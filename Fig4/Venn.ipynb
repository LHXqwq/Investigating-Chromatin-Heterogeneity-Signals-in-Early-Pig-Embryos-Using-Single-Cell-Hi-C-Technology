# %%
#PA diff e-p genes
from matplotlib_venn import venn2, venn2_circles
import matplotlib.pyplot as plt
import matplotlib
from scipy.stats import hypergeom
from IPython.display import SVG, display

plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams['svg.hashsalt'] = 'hello'

# ====================
# 配置参数
# ====================
# 重要提示：需要根据实际研究背景修改总基因数M
M = 20289  # 假设基因组总基因数（需按实际调整！）
subset_values = (1763, 1762, 3716)  # (A_only, B_only, AB)

# ====================
# 统计检验计算
# ====================
# 计算Jaccard相似性系数
union = subset_values[0] + subset_values[1] + subset_values[2]
jaccard = subset_values[2] / union

# 超几何检验计算
n_A = subset_values[0] + subset_values[2]  # 2C基因总数
n_B = subset_values[1] + subset_values[2]  # 4C基因总数
k = subset_values[2]  # 重叠基因数

# 超几何分布公式：P(X >= k)
p_value = hypergeom.sf(
    k-1,  # 生存函数计算的是P(X > k-1)即P(X >=k)
    M,    # 总基因数
    n_A,  # 成功元素数（2C基因）
    n_B   # 抽样数（4C基因）
)

# ====================
# 可视化参数设置
# ====================
matplotlib.rcParams.update({
    'font.size': 10,
    'font.weight': 'bold'
})
plt.rcParams['font.family'] = 'DejaVu Sans'  # Linux通用字体
# ====================
# 绘制专业图表
# ====================
fig, ax = plt.subplots()

# 绘制Venn图主体
venn = venn2(
    subsets=subset_values,
    set_labels=(
        f'2C diff E-P genes', 
        f'4C diff E-P genes'
    ),
    set_colors=('#1f77b4', '#ff7f0e'),
    alpha=0.7,
    ax=ax
)

print(f"Hypergeometric test: p = {p_value:.1e}")
print(f"Jaccard index = {jaccard:.3f}")
      
# 添加统计标注
stats_text = (
    f"Hypergeometric test: p = {p_value:.1e}\n"
    f"Jaccard index = {jaccard:.3f}"
)
ax.text(
    0.5, -0.05, 
    stats_text,
    ha='center', 
    va='top',
    transform=ax.transAxes,
    fontsize=10,
    bbox=dict(
        boxstyle='round', 
        facecolor='white', 
        alpha=0.8, 
        edgecolor='gray'
    )
)

# ====================
# 图形增强
# ====================
# 添加虚线轮廓
venn2_circles(
    subsets=subset_values, 
    linestyle='--', 
    linewidth=1, 
    ax=ax,
    color='gray'
)


# 标题设置
ax.set_title(
    "PA: Differential E-P Genes", 
    fontweight='bold',
    fontsize=10
)

# ====================
# 输出控制
# ====================
plt.tight_layout()

plt.savefig('PA_E-P_genes_venn_with_stats.svg', dpi=300, bbox_inches='tight', transparent=True)
#display(SVG(filename='PA_E-P_genes_venn_with_stats.svg'))
# Out:
# Hypergeometric test: p = 0.0e+00
# Jaccard index = 0.513

# %%
#IVF diff e-p genes
from matplotlib_venn import venn2, venn2_circles
import matplotlib.pyplot as plt
import matplotlib
from scipy.stats import hypergeom
from IPython.display import SVG, display

plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams['svg.hashsalt'] = 'hello'

# ====================
# 配置参数
# ====================
# 重要提示：需要根据实际研究背景修改总基因数M
M = 20289  # 假设基因组总基因数（需按实际调整！）
subset_values = (1676, 1966, 4063)  # (A_only, B_only, AB)

# ====================
# 统计检验计算
# ====================
# 计算Jaccard相似性系数
union = subset_values[0] + subset_values[1] + subset_values[2]
jaccard = subset_values[2] / union

# 超几何检验计算
n_A = subset_values[0] + subset_values[2]  # 2C基因总数
n_B = subset_values[1] + subset_values[2]  # 4C基因总数
k = subset_values[2]  # 重叠基因数

# 超几何分布公式：P(X >= k)
p_value = hypergeom.sf(
    k-1,  # 生存函数计算的是P(X > k-1)即P(X >=k)
    M,    # 总基因数
    n_A,  # 成功元素数（2C基因）
    n_B   # 抽样数（4C基因）
)

# ====================
# 可视化参数设置
# ====================
matplotlib.rcParams.update({
    'font.size': 10,
    'font.weight': 'bold'
})
plt.rcParams['font.family'] = 'DejaVu Sans'  # Linux通用字体
# ====================
# 绘制专业图表
# ====================
fig, ax = plt.subplots()

# 绘制Venn图主体
venn = venn2(
    subsets=subset_values,
    set_labels=(
        f'2C diff E-P genes', 
        f'4C diff E-P genes'
    ),
    set_colors=('#1f77b4', '#ff7f0e'),
    alpha=0.7,
    ax=ax
)

print(f"Hypergeometric test: p = {p_value:.1e}")
print(f"Jaccard index = {jaccard:.3f}")
      
# 添加统计标注
stats_text = (
    f"Hypergeometric test: p = {p_value:.1e}\n"
    f"Jaccard index = {jaccard:.3f}"
)
ax.text(
    0.5, -0.05, 
    stats_text,
    ha='center', 
    va='top',
    transform=ax.transAxes,
    fontsize=10,
    bbox=dict(
        boxstyle='round', 
        facecolor='white', 
        alpha=0.8, 
        edgecolor='gray'
    )
)

# ====================
# 图形增强
# ====================
# 添加虚线轮廓
venn2_circles(
    subsets=subset_values, 
    linestyle='--', 
    linewidth=1, 
    ax=ax,
    color='gray'
)


# 标题设置
ax.set_title(
    "IVF: Differential E-P Genes", 
    fontweight='bold',
    fontsize=10
)

# ====================
# 输出控制
# ====================
plt.tight_layout()
plt.savefig('IVF_E-P_genes_venn_with_stats.svg', dpi=300, bbox_inches='tight', transparent=True)
#display(SVG(filename='IVF_E-P_genes_venn_with_stats.svg'))
# Out:
# Hypergeometric test: p = 0.0e+00
# Jaccard index = 0.527

# %%
#PA 2C
from matplotlib_venn import venn3
import matplotlib.pyplot as plt
import matplotlib

# 更新字体大小
matplotlib.rcParams.update({'font.size': 14})

# 从文件中读取集合元素
def read_set_from_file(filename):
    with open(filename, 'r') as file:
        elements = set(line.strip() for line in file)
    return elements

# 从文件中读取集合元素
set1 = read_set_from_file('pa_2c_dipid.txt')
set2 = read_set_from_file('PA_minorMDid.txt')
set3 = read_set_from_file('PA_minorZGAid.txt')

# 计算交集和并集的数量
intersection_count = len(set1 & set2 & set3)
union_count = len(set1 | set2 | set3)

# 创建一个等比例的3集合Venn图
venn = venn3(subsets=(len(set1 - set2 - set3), len(set2 - set1 - set3), len(set1 & set2 - set3),
               len(set3 - set1 - set2), len(set1 & set3 - set2), len(set2 & set3 - set1),
               len(set1 & set2 & set3)),
      set_labels=('PA 2C inter-blastomere DEGs', '2C MD', '2C minor ZGA'))

# 调整标签位置
venn.get_label_by_id('A').set_y(0.4)  # 移动A标签，即2C Inter-Blastomere DEGs

#plt.title("2C significantly bins")
plt.show()

print("Intersection count:", intersection_count)
print("Union count:", union_count)

# 计算并集
union_set = set1.union(set2, set3)

# 写入并集到新文件
with open('PA_2c_union.txt', 'w') as file:
    for element in union_set:
        file.write(element + '\n')

print("Union written to union_set.txt file successfully.")
# Out:
# Intersection count: 0
# Union count: 4757
# Union written to union_set.txt file successfully.

# %%
#PA 4C
from matplotlib_venn import venn3
import matplotlib.pyplot as plt
import matplotlib

# 更新字体大小
matplotlib.rcParams.update({'font.size': 14})

# 从文件中读取集合元素
def read_set_from_file(filename):
    with open(filename, 'r') as file:
        elements = set(line.strip() for line in file)
    return elements

# 从文件中读取集合元素
set1 = read_set_from_file('pa_4c_dipid.txt')
set2 = read_set_from_file('PA_majorMDid.txt')
set3 = read_set_from_file('PA_majorZGAid.txt')

# 计算交集和并集的数量
intersection_count = len(set1 & set2 & set3)
union_count = len(set1 | set2 | set3)

# 创建一个等比例的3集合Venn图
venn = venn3(subsets=(len(set1 - set2 - set3), len(set2 - set1 - set3), len(set1 & set2 - set3),
               len(set3 - set1 - set2), len(set1 & set3 - set2), len(set2 & set3 - set1),
               len(set1 & set2 & set3)),
      set_labels=('PA 4C inter-blastomere DEGs', '4C MD', '4C major ZGA'))

# 调整标签位置
venn.get_label_by_id('A').set_y(0.4)  # 移动A标签，即2C Inter-Blastomere DEGs

#plt.title("2C significantly bins")
plt.show()

print("Intersection count:", intersection_count)
print("Union count:", union_count)

# 计算并集
union_set = set1.union(set2, set3)

# 写入并集到新文件
with open('PA_4c_union.txt', 'w') as file:
    for element in union_set:
        file.write(element + '\n')

print("Union written to union_set.txt file successfully.")
# Out:
# Intersection count: 0
# Union count: 6509
# Union written to union_set.txt file successfully.

# %%
#IVF 2C
from matplotlib_venn import venn3
import matplotlib.pyplot as plt
import matplotlib

# 更新字体大小
matplotlib.rcParams.update({'font.size': 14})

# 从文件中读取集合元素
def read_set_from_file(filename):
    with open(filename, 'r') as file:
        elements = set(line.strip() for line in file)
    return elements

# 从文件中读取集合元素
set1 = read_set_from_file('ivf_2c_dipid.txt')
set2 = read_set_from_file('IVF_minorMDid.txt')
set3 = read_set_from_file('IVF_minorZGAid.txt')

# 计算交集和并集的数量
intersection_count = len(set1 & set2 & set3)
union_count = len(set1 | set2 | set3)

# 创建一个等比例的3集合Venn图
venn = venn3(subsets=(len(set1 - set2 - set3), len(set2 - set1 - set3), len(set1 & set2 - set3),
               len(set3 - set1 - set2), len(set1 & set3 - set2), len(set2 & set3 - set1),
               len(set1 & set2 & set3)),
      set_labels=('IVF 2C inter-blastomere DEGs', '2C MD', '2C minor ZGA'))

# 调整标签位置
venn.get_label_by_id('A').set_y(0.4)  # 移动A标签，即2C Inter-Blastomere DEGs

#plt.title("2C significantly bins")
plt.show()

print("Intersection count:", intersection_count)
print("Union count:", union_count)

# 计算并集
union_set = set1.union(set2, set3)

# 写入并集到新文件
with open('IVF_2c_union.txt', 'w') as file:
    for element in union_set:
        file.write(element + '\n')

print("Union written to union_set.txt file successfully.")
# Out:
# Intersection count: 0
# Union count: 896
# Union written to union_set.txt file successfully.

# %%
#IVF 4C
from matplotlib_venn import venn3
import matplotlib.pyplot as plt
import matplotlib

# 更新字体大小
matplotlib.rcParams.update({'font.size': 14})

# 从文件中读取集合元素
def read_set_from_file(filename):
    with open(filename, 'r') as file:
        elements = set(line.strip() for line in file)
    return elements

# 从文件中读取集合元素
set1 = read_set_from_file('ivf_4c_dipid.txt')
set2 = read_set_from_file('IVF_majorMDid.txt')
set3 = read_set_from_file('IVF_majorZGAid.txt')

# 计算交集和并集的数量
intersection_count = len(set1 & set2 & set3)
union_count = len(set1 | set2 | set3)

# 创建一个等比例的3集合Venn图
venn = venn3(subsets=(len(set1 - set2 - set3), len(set2 - set1 - set3), len(set1 & set2 - set3),
               len(set3 - set1 - set2), len(set1 & set3 - set2), len(set2 & set3 - set1),
               len(set1 & set2 & set3)),
      set_labels=('IVF 4C inter-blastomere DEGs', '4C MD', '4C major ZGA'))

# 调整标签位置
venn.get_label_by_id('A').set_y(0.4)  # 移动A标签，即2C Inter-Blastomere DEGs

#plt.title("2C significantly bins")
plt.show()

print("Intersection count:", intersection_count)
print("Union count:", union_count)

# 计算并集
union_set = set1.union(set2, set3)

# 写入并集到新文件
with open('IVF_4c_union.txt', 'w') as file:
    for element in union_set:
        file.write(element + '\n')

print("Union written to union_set.txt file successfully.")
# Out:
# Intersection count: 0
# Union count: 7028
# Union written to union_set.txt file successfully.

# %%
# !cd /home/lihaoxing/E-Pgenes_inter-blastomere_overlap 

#相关的基因文件如下
#IVF_2C_diff_EPgenes.H3K27ac.0.01.txt
#IVF_4C_diff_EPgenes.H3K27ac.0.01.txt
#ivf_2c_dipid.txt
#ivf_4c_dipid.txt

#PA_2C_diff_EPgenes.H3K27ac.0.01.txt
#PA_4C_diff_EPgenes.H3K27ac.0.01.txt
#pa_2c_dipid.txt
#pa_4c_dipid.txt

# %%
#PA 2C diff e-p genes，inter-blastomere DEGs
from matplotlib_venn import venn2, venn2_circles
import matplotlib.pyplot as plt
import matplotlib
from scipy.stats import hypergeom
from IPython.display import SVG, display

plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams['svg.hashsalt'] = 'hello'

# 重要提示：需要根据实际研究背景修改总基因数M
M = 20289  # 假设基因组总基因数（需按实际调整！）
subset_values = (5337, 476, 142)  # (A_only, B_only, AB)

# ====================
# 统计检验计算
# ====================
# 计算Jaccard相似性系数
union = subset_values[0] + subset_values[1] + subset_values[2]
jaccard = subset_values[2] / union

# 超几何检验计算
n_A = subset_values[0] + subset_values[2]  # 2C基因总数
n_B = subset_values[1] + subset_values[2]  # 4C基因总数
k = subset_values[2]  # 重叠基因数

# 超几何分布公式：P(X >= k)
p_value = hypergeom.sf(
    k-1,  # 生存函数计算的是P(X > k-1)即P(X >=k)
    M,    # 总基因数
    n_A,  # 成功元素数（2C基因）
    n_B   # 抽样数（4C基因）
)

# ====================
# 可视化参数设置
# ====================
matplotlib.rcParams.update({
    'font.size': 10,
    'font.weight': 'bold'
})
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams['svg.hashsalt'] = 'hello'
# ====================
# 绘制专业图表
# ====================
fig, ax = plt.subplots()

# 绘制Venn图主体
venn = venn2(
    subsets=subset_values,
    set_labels=(
        f'PA 2C diff E-P genes', 
        f'PA 2C inter-blastomere DEGs'
    ),
    set_colors=('#1f77b4', '#ff7f0e'),
    alpha=0.7,
    ax=ax
)

print(f"Hypergeometric test: p = {p_value:.1e}")
print(f"Jaccard index = {jaccard:.3f}")
      
# 添加统计标注
stats_text = (
    f"Hypergeometric test: p = {p_value:.1e}\n"
    f"Jaccard index = {jaccard:.3f}"
)
ax.text(
    0.5, -0.05, 
    stats_text,
    ha='center', 
    va='top',
    transform=ax.transAxes,
    fontsize=10,
    bbox=dict(
        boxstyle='round', 
        facecolor='white', 
        alpha=0.8, 
        edgecolor='gray'
    )
)

# ====================
# 图形增强
# ====================
# 添加虚线轮廓
venn2_circles(
    subsets=subset_values, 
    linestyle='--', 
    linewidth=1, 
    ax=ax,
    color='gray'
)

# ====================
# 输出控制
# ====================
plt.tight_layout()
plt.savefig('PA_2C_EPI_inter-blastomere_overlap.svg', dpi=300, bbox_inches='tight', transparent=True)
#display(SVG(filename='PA_2C_EPI_inter-blastomere_overlap.svg'))
# Out:
# Hypergeometric test: p = 9.9e-01
# Jaccard index = 0.024

# %%
#PA 4C diff e-p genes，inter-blastomere DEGs
from matplotlib_venn import venn2, venn2_circles
import matplotlib.pyplot as plt
import matplotlib
from scipy.stats import hypergeom
from IPython.display import SVG, display

plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams['svg.hashsalt'] = 'hello'

# 重要提示：需要根据实际研究背景修改总基因数M
M = 20289  # 假设基因组总基因数（需按实际调整！）
subset_values = (5140, 843, 338)  # (A_only, B_only, AB)

# ====================
# 统计检验计算
# ====================
# 计算Jaccard相似性系数
union = subset_values[0] + subset_values[1] + subset_values[2]
jaccard = subset_values[2] / union

# 超几何检验计算
n_A = subset_values[0] + subset_values[2]  # 2C基因总数
n_B = subset_values[1] + subset_values[2]  # 4C基因总数
k = subset_values[2]  # 重叠基因数

# 超几何分布公式：P(X >= k)
p_value = hypergeom.sf(
    k-1,  # 生存函数计算的是P(X > k-1)即P(X >=k)
    M,    # 总基因数
    n_A,  # 成功元素数（2C基因）
    n_B   # 抽样数（4C基因）
)

# ====================
# 可视化参数设置
# ====================
matplotlib.rcParams.update({
    'font.size': 10,
    'font.weight': 'bold'
})
plt.rcParams['font.family'] = 'DejaVu Sans'  # Linux通用字体
# ====================
# 绘制专业图表
# ====================
fig, ax = plt.subplots()

# 绘制Venn图主体
venn = venn2(
    subsets=subset_values,
    set_labels=(
        f'PA 4C diff E-P genes', 
        f'PA 4C inter-blastomere DEGs'
    ),
    set_colors=('#1f77b4', '#ff7f0e'),
    alpha=0.7,
    ax=ax
)

print(f"Hypergeometric test: p = {p_value:.1e}")
print(f"Jaccard index = {jaccard:.3f}")
      
# 添加统计标注
stats_text = (
    f"Hypergeometric test: p = {p_value:.1e}\n"
    f"Jaccard index = {jaccard:.3f}"
)
ax.text(
    0.5, -0.05, 
    stats_text,
    ha='center', 
    va='top',
    transform=ax.transAxes,
    fontsize=10,
    bbox=dict(
        boxstyle='round', 
        facecolor='white', 
        alpha=0.8, 
        edgecolor='gray'
    )
)

# ====================
# 图形增强
# ====================
# 添加虚线轮廓
venn2_circles(
    subsets=subset_values, 
    linestyle='--', 
    linewidth=1, 
    ax=ax,
    color='gray'
)

# ====================
# 输出控制
# ====================
plt.tight_layout()
plt.savefig('PA_4C_EPI_inter-blastomere_overlap.svg', dpi=300, bbox_inches='tight', transparent=True)
#display(SVG(filename='PA_4C_EPI_inter-blastomere_overlap.svg'))
# Out:
# Hypergeometric test: p = 1.0e-01
# Jaccard index = 0.053

# %%
#IVF 2C diff e-p genes，inter-blastomere DEGs
from matplotlib_venn import venn2, venn2_circles
import matplotlib.pyplot as plt
import matplotlib
from scipy.stats import hypergeom
from IPython.display import SVG, display

plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams['svg.hashsalt'] = 'hello'

# 重要提示：需要根据实际研究背景修改总基因数M
M = 20289  # 假设基因组总基因数（需按实际调整！）
subset_values = (5552, 510, 187)  # (A_only, B_only, AB)

# ====================
# 统计检验计算
# ====================
# 计算Jaccard相似性系数
union = subset_values[0] + subset_values[1] + subset_values[2]
jaccard = subset_values[2] / union

# 超几何检验计算
n_A = subset_values[0] + subset_values[2]  # 2C基因总数
n_B = subset_values[1] + subset_values[2]  # 4C基因总数
k = subset_values[2]  # 重叠基因数

# 超几何分布公式：P(X >= k)
p_value = hypergeom.sf(
    k-1,  # 生存函数计算的是P(X > k-1)即P(X >=k)
    M,    # 总基因数
    n_A,  # 成功元素数（2C基因）
    n_B   # 抽样数（4C基因）
)

# ====================
# 可视化参数设置
# ====================
matplotlib.rcParams.update({
    'font.size': 10,
    'font.weight': 'bold'
})
plt.rcParams['font.family'] = 'DejaVu Sans'  # Linux通用字体
# ====================
# 绘制专业图表
# ====================
fig, ax = plt.subplots()

# 绘制Venn图主体
venn = venn2(
    subsets=subset_values,
    set_labels=(
        f'IVF 2C diff E-P genes', 
        f'IVF 2C inter-blastomere DEGs'
    ),
    set_colors=('#1f77b4', '#ff7f0e'),
    alpha=0.7,
    ax=ax
)

print(f"Hypergeometric test: p = {p_value:.1e}")
print(f"Jaccard index = {jaccard:.3f}")
      
# 添加统计标注
stats_text = (
    f"Hypergeometric test: p = {p_value:.1e}\n"
    f"Jaccard index = {jaccard:.3f}"
)
ax.text(
    0.5, -0.05, 
    stats_text,
    ha='center', 
    va='top',
    transform=ax.transAxes,
    fontsize=10,
    bbox=dict(
        boxstyle='round', 
        facecolor='white', 
        alpha=0.8, 
        edgecolor='gray'
    )
)

# ====================
# 图形增强
# ====================
# 添加虚线轮廓
venn2_circles(
    subsets=subset_values, 
    linestyle='--', 
    linewidth=1, 
    ax=ax,
    color='gray'
)

# ====================
# 输出控制
# ====================
plt.tight_layout()
plt.savefig('IVF_2C_EPI_inter-blastomere_overlap.svg', dpi=300, bbox_inches='tight', transparent=True)
#display(SVG(filename='IVF_2C_EPI_inter-blastomere_overlap.svg'))
# Out:
# Hypergeometric test: p = 8.2e-01
# Jaccard index = 0.030

# %%
#IVF 4C diff e-p genes，inter-blastomere DEGs
from matplotlib_venn import venn2, venn2_circles
import matplotlib.pyplot as plt
import matplotlib
from scipy.stats import hypergeom
from IPython.display import SVG, display

plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams['svg.hashsalt'] = 'hello'

# 重要提示：需要根据实际研究背景修改总基因数M
M = 20289  # 假设基因组总基因数（需按实际调整！）
subset_values = (5271, 1358, 758)  # (A_only, B_only, AB)

# ====================
# 统计检验计算
# ====================
# 计算Jaccard相似性系数
union = subset_values[0] + subset_values[1] + subset_values[2]
jaccard = subset_values[2] / union

# 超几何检验计算
n_A = subset_values[0] + subset_values[2]  # 2C基因总数
n_B = subset_values[1] + subset_values[2]  # 4C基因总数
k = subset_values[2]  # 重叠基因数

# 超几何分布公式：P(X >= k)
p_value = hypergeom.sf(
    k-1,  # 生存函数计算的是P(X > k-1)即P(X >=k)
    M,    # 总基因数
    n_A,  # 成功元素数（2C基因）
    n_B   # 抽样数（4C基因）
)

# ====================
# 可视化参数设置
# ====================
matplotlib.rcParams.update({
    'font.size': 10,
    'font.weight': 'bold'
})
plt.rcParams['font.family'] = 'DejaVu Sans'  # Linux通用字体
# ====================
# 绘制专业图表
# ====================
fig, ax = plt.subplots()

# 绘制Venn图主体
venn = venn2(
    subsets=subset_values,
    set_labels=(
        f'IVF 4C diff E-P genes', 
        f'IVF 4C inter-blastomere DEGs'
    ),
    set_colors=('#1f77b4', '#ff7f0e'),
    alpha=0.7,
    ax=ax
)

print(f"Hypergeometric test: p = {p_value:.1e}")
print(f"Jaccard index = {jaccard:.3f}")
      
# 添加统计标注
stats_text = (
    f"Hypergeometric test: p = {p_value:.1e}\n"
    f"Jaccard index = {jaccard:.3f}"
)
ax.text(
    0.5, -0.05, 
    stats_text,
    ha='center', 
    va='top',
    transform=ax.transAxes,
    fontsize=10,
    bbox=dict(
        boxstyle='round', 
        facecolor='white', 
        alpha=0.8, 
        edgecolor='gray'
    )
)

# ====================
# 图形增强
# ====================
# 添加虚线轮廓
venn2_circles(
    subsets=subset_values, 
    linestyle='--', 
    linewidth=1, 
    ax=ax,
    color='gray'
)

# ====================
# 输出控制
# ====================
plt.tight_layout()
plt.savefig('IVF_4C_EPI_inter-blastomere_overlap.svg', dpi=300, bbox_inches='tight', transparent=True)
#display(SVG(filename='IVF_4C_EPI_inter-blastomere_overlap.svg'))
# Out:
# Hypergeometric test: p = 9.3e-11
# Jaccard index = 0.103
