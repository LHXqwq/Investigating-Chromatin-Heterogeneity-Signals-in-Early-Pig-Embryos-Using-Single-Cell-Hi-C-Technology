# %%
#2024.7.23最新模拟，
#以单个细胞为单位，模拟2C发育到4C，用上所有通过QC的数据
#2代表 C1，1代表 C2，0代表 Undefined
#PA模拟
import random
import time

def simulate_cell_division(cells, p1, p2, p3, p4,p5,p7,p8,p9,p10,p11,p13,p14,p15,p16,p17):
    cells_4 = []
    for cell in cells:
        rand_num_1 = random.random()
        
        if cell == [2]:
            if rand_num_1 < p1:
                pre_4 =[2, 2]
            elif rand_num_1 < p1 + p2:
                pre_4 =[2, 1]
            elif rand_num_1 < p1 + p2 + p3:
                pre_4 =[1, 1]
            elif rand_num_1 < p1 + p2 + p3 + p4:
                pre_4 =[2, 0]
            elif rand_num_1 < p1 + p2 + p3 + p4 +p5:
                pre_4 =[1, 0]
            else:
                pre_4 =[0, 0]
                
            c4=pre_4
            cells_4.append(c4)
            
        elif cell == [1]:
            if rand_num_1 < p1:
                pre_4 =[2, 2]
            elif rand_num_1 < p1 + p2:
                pre_4 =[2, 1]
            elif rand_num_1 < p1 + p2 + p3:
                pre_4 =[1, 1]
            elif rand_num_1 < p1 + p2 + p3 + p4:
                pre_4 =[2, 0]
            elif rand_num_1 < p1 + p2 + p3 + p4 +p5:
                pre_4 =[1, 0]
            else:
                pre_4 =[0, 0]
                
            c4=pre_4
            cells_4.append(c4)
            
        elif cell == [0]:
            if rand_num_1 < p7:
                pre_4 =[2, 2]
            elif rand_num_1 < p7 + p8:
                pre_4 =[2, 1]
            elif rand_num_1 < p7 + p8 + p9:
                pre_4 =[1, 1]
            elif rand_num_1 < p7 + p8 + p9 + p10:
                pre_4 =[2, 0]
            elif rand_num_1 < p7 + p8 + p9 + p10 + p11:
                pre_4 =[1, 0]
            else:
                pre_4 =[0, 0]
                
            c4=pre_4
            cells_4.append(c4)
            
    return cells_4

def count_combinations_4_cells(cells_4):
    count_c1 = 0
    count_c2 = 0
    count_un = 0

    total_count = len(cells_4) * 2

    for cell in cells_4:
        if cell.count(2) == 2:
            count_c1 += 2
        elif cell.count(2) == 1 and cell.count(1) == 1:
            count_c1 += 1
            count_c2 += 1
        elif cell.count(1) == 2:
            count_c2 += 2
        elif cell.count(2) == 1 and cell.count(0) == 1:
            count_c1 += 1
            count_un += 1
        elif cell.count(1) == 1 and cell.count(0) == 1:
            count_c2 += 1
            count_un += 1
        elif cell.count(0) == 2:
            count_un += 2
            
    probability_c1 = count_c1 / total_count
    probability_c2 = count_c2 / total_count
    probability_un = count_un / total_count

    return (
        probability_c1,
        probability_c2,
        probability_un
    )

def count_elements(lst):
    # Flatten the list
    flat_list = [item for sublist in lst for item in sublist]
    
    count_c1 = flat_list.count(2)
    count_c2 = flat_list.count(1)
    count_un = flat_list.count(0)
    
    total_count = count_c1 + count_c2 + count_un
    
    if total_count == 0:
        raise ValueError("The total count of elements is zero, cannot calculate probabilities.")
    
    probability_c1 = count_c1 / total_count
    probability_c2 = count_c2 / total_count
    probability_un = count_un / total_count
    
    return probability_c1, probability_c2, probability_un


def evaluate_difference(observed_probabilities, simulated_probabilities):
    difference = sum(abs(obs_prob - sim_prob) for obs_prob, sim_prob in zip(observed_probabilities, simulated_probabilities))
    return difference

def generate_positive_numbers(num_variables):
    # 生成 num_variables 个介于 0 到 1 之间的随机数
    numbers = [random.random() for _ in range(num_variables)]

    # 计算累加之和
    total_sum = sum(numbers)

    # 归一化，使得累加之和等于1
    normalized_numbers = [num / total_sum for num in numbers]

    return normalized_numbers

# 基于真实2细胞数据，等比例生成1000个细胞
cells_2 = [[2] for _ in range(542)] + [[1] for _ in range(346)] + [[0] for _ in range(112)]
#真实的4C比例，包括所有4C
true_lists = [[2] for _ in range(546)] + [[1] for _ in range(443)] + [[0] for _ in range(11)]

true_probabilities = count_elements(true_lists)
print(true_probabilities)
# Out:
# (0.546, 0.443, 0.011)

# %%
#PA 模拟
import random
import numpy as np
from deap import base, creator, tools, algorithms
import matplotlib.pyplot as plt
import time

def evaluate_difference(observed_probabilities, simulated_probabilities):
    difference = sum(abs(obs_prob - sim_prob) for obs_prob, sim_prob in zip(observed_probabilities, simulated_probabilities))
    return difference

# 定义适应度评估函数
def evaluate_individual(individual):
    p1, p2, p3, p4,p5,p6,p7,p8,p9,p10,p11,p12,p13,p14,p15,p16,p17,p18 = individual
    sum1 = p1+p2+p3+p4+p5+p6
    sum2 = p7+p8+p9+p10+p11+p12
    sum3 = p13+p14+p15+p16+p17+p18
    p1 = p1/sum1
    p2 = p2/sum1
    p3 = p3/sum1
    p4 = p4/sum1
    p5 = p5/sum1
    p6 = p6/sum1
    p7 = p7/sum2
    p8 = p8/sum2
    p9 = p9/sum2
    p10 = p10/sum2
    p11 = p11/sum2
    p12 = p12/sum2
    p13 = p13/sum3
    p14 = p14/sum3
    p15 = p15/sum3
    p16 = p16/sum3
    p17 = p17/sum3
    p18 = p18/sum3
    # 如果任意一个参数小于0，则直接返回一个非常大的适应度值
    if any(p < 0 for p in [p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12, p13, p14, p15, p16, p17, p18]):
        difference=10
        return difference,
    else:
        simulated_cells_4 = simulate_cell_division(cells_2, p1, p2, p3, p4,p5,p7,p8,p9,p10,p11,p13,p14,p15,p16,p17)
        simulated_probabilities = count_combinations_4_cells(simulated_cells_4)
        difference = evaluate_difference(true_probabilities, simulated_probabilities)
        return difference,

# 定义遗传算法相关参数
population_size = 3200
num_generations = 200
num_parents = 1600
num_offspring = population_size - num_parents
num_repeats = 1

# 创建遗传算法工具箱
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))  # 通过使用负数的weights，我们可以建立最小化适应值的优化过程
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, 0, 1)  # 参数取值范围为[0, 1]
toolbox.register("individual", tools.initRepeat, creator.Individual, lambda: abs(random.uniform(0, 1)), n=18)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("evaluate", evaluate_individual)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=1, indpb=0.1)
toolbox.register("select", tools.selTournament, tournsize=3)

simulated_results = []  # 存储模拟结果
best_p_values = []  # 存储最佳p值

# 创建一个新的子图
#plt.figure(figsize=(5, 20))
best_fitnesses = []  # 存储每次迭代的最佳适应度值
# 迭代运行多次
for repeat in range(num_repeats):
    print(f"Repeat {repeat + 1}:")
    start_time = time.time()  # 记录模拟开始时间
    
    # 初始化种群
    population = toolbox.population(n=population_size)
    
    # 迭代演化
    for generation in range(num_generations):
        offspring = []
        
        # 通过选择父代个体、交叉操作和变异操作来生成指定数量的子代个体，并将其保存在子代列表中，以备后续的适应度评估和种群更新使用
        for _ in range(num_offspring):
            parent1 = random.choice(population)
            parent2 = random.choice(population)
            child = toolbox.clone(parent1)
            toolbox.mate(child, parent2)
            toolbox.mutate(child)
            offspring.append(child)
        
        # 评估子代适应度评，并将适应度值赋给相应的个体对象，以便进行后续的遗传算法操作。
        fitnesses = map(toolbox.evaluate, offspring)
        #print(toolbox.evaluate)
        for ind, fit in zip(offspring, fitnesses):
            ind.fitness.values = fit
        
        # 更新种群
        population = toolbox.select(population + offspring, k=population_size)
        # 存储每次迭代的最佳适应度值
        best_fitness = tools.selBest(population, k=1)[0].fitness.values[0]
        best_fitnesses.append(best_fitness) 
        
    # 获取最优解
    best_individual = tools.selBest(population, k=1)[0]
    best_p1, best_p2, best_p3, best_p4 , best_p5, best_p6, best_p7, best_p8, best_p9, best_p10, best_p11, best_p12, best_p13, best_p14, best_p15, best_p16, best_p17, best_p18= best_individual
    sum1 = best_p1+best_p2+best_p3+best_p4+best_p5+best_p6
    sum2 = best_p7+best_p8+best_p9+best_p10+best_p11+best_p12
    sum3 = best_p13+best_p14+best_p15+best_p16+best_p17+best_p18
    best_p1 = best_p1/sum1
    best_p2 = best_p2/sum1
    best_p3 = best_p3/sum1
    best_p4 = best_p4/sum1
    best_p5 = best_p5/sum1
    best_p6 = best_p6/sum1
    best_p7 = best_p7/sum2
    best_p8 = best_p8/sum2
    best_p9 = best_p9/sum2
    best_p10 = best_p10/sum2
    best_p11 = best_p11/sum2
    best_p12 = best_p12/sum2
    best_p13 = best_p13/sum3
    best_p14 = best_p14/sum3
    best_p15 = best_p15/sum3
    best_p16 = best_p16/sum3
    best_p17 = best_p17/sum3
    best_p18 = best_p18/sum3
    
    # 打印结果
    print("最佳p值:", best_p1, best_p2, best_p3, best_p4 , best_p5, best_p6, best_p7, best_p8, best_p9, best_p10, best_p11, best_p12, best_p13, best_p14, best_p15, best_p16, best_p17, best_p18)
    simulated_cells_4 = simulate_cell_division(cells_2, best_p1, best_p2, best_p3, best_p4,best_p5,best_p7,best_p8,best_p9,best_p10,best_p11,best_p13,best_p14,best_p15,best_p16,best_p17)
    simulated_probabilities = count_combinations_4_cells(simulated_cells_4)
    print("模拟结果:", simulated_probabilities)
    print("适应度:", tools.selBest(population, k=1)[0].fitness.values[0])
    print("diff:", evaluate_difference(true_probabilities, simulated_probabilities))
    
    end_time = time.time()  # 记录模拟结束时间
    elapsed_time = end_time - start_time  # 计算模拟运行时间
    elapsed_time_minutes = elapsed_time / 60  # 转换为分钟
    print("模拟用时", repeat + 1, ":", elapsed_time_minutes, "分钟")
    # 存储模拟结果和最佳p值
    simulated_results.append(simulated_probabilities)
    best_p_values.append([best_p1, best_p2, best_p3, best_p4])
    
    ## 绘制每次迭代的最佳适应度值变化曲线
    #plt.subplot(6, 1, repeat+1)  # 创建子图
    #best_fitnesses = [tools.selBest(population, k=1)[0].fitness.values[0] for population in populations]
    #plt.plot(range(num_generations), best_fitnesses, marker='o')
    #plt.xlabel('Generation')
    #plt.ylabel('Best Fitness')
    #plt.ylim(0, 0.2)  # 设置y轴范围
    #plt.title(f'Repeat {repeat+1}')
    #plt.grid(True)
    # 重置best_fitnesses列表，以便进行下一次迭代
    best_fitnesses = []

# 调整子图的间距
#plt.tight_layout()

# 显示所有子图
#plt.show()
# Out:
# Repeat 1:
# 最佳p值: 0.14237189409390194 0.7649201098819893 0.08199303903750413 0.0049147966897154765 0.0032566929729530587 0.0025434673239361403 0.46455962928096983 0.25461232313169635 0.14136438116976396 0.09650957982939828 0.040619299804204034 0.002334786783967506 0.12269335054665159 0.14430726374568859 0.09446713013800254 0.16884713382705033 0.17838139013649268 0.29130373160611434
# 模拟结果: (0.529, 0.4595, 0.0115)
# 适应度: 0.0
# diff: 0.03400000000000003
# 模拟用时 1 : 2.523296296596527 分钟

# %%
#2024.7.23最新模拟，
#以单个细胞为单位，模拟2C发育到4C，用上所有通过QC的数据
#2代表 C1，1代表 C2，0代表 Undefined
#IVF模拟
import random
import time

def simulate_cell_division(cells, p1, p2, p3, p4,p5,p7,p8,p9,p10,p11,p13,p14,p15,p16,p17):
    cells_4 = []
    for cell in cells:
        rand_num_1 = random.random()
        
        if cell == [2]:
            if rand_num_1 < p1:
                pre_4 =[2, 2]
            elif rand_num_1 < p1 + p2:
                pre_4 =[2, 1]
            elif rand_num_1 < p1 + p2 + p3:
                pre_4 =[1, 1]
            elif rand_num_1 < p1 + p2 + p3 + p4:
                pre_4 =[2, 0]
            elif rand_num_1 < p1 + p2 + p3 + p4 +p5:
                pre_4 =[1, 0]
            else:
                pre_4 =[0, 0]
                
            c4=pre_4
            cells_4.append(c4)
            
        elif cell == [1]:
            if rand_num_1 < p1:
                pre_4 =[2, 2]
            elif rand_num_1 < p1 + p2:
                pre_4 =[2, 1]
            elif rand_num_1 < p1 + p2 + p3:
                pre_4 =[1, 1]
            elif rand_num_1 < p1 + p2 + p3 + p4:
                pre_4 =[2, 0]
            elif rand_num_1 < p1 + p2 + p3 + p4 +p5:
                pre_4 =[1, 0]
            else:
                pre_4 =[0, 0]
                
            c4=pre_4
            cells_4.append(c4)
            
        elif cell == [0]:
            if rand_num_1 < p7:
                pre_4 =[2, 2]
            elif rand_num_1 < p7 + p8:
                pre_4 =[2, 1]
            elif rand_num_1 < p7 + p8 + p9:
                pre_4 =[1, 1]
            elif rand_num_1 < p7 + p8 + p9 + p10:
                pre_4 =[2, 0]
            elif rand_num_1 < p7 + p8 + p9 + p10 + p11:
                pre_4 =[1, 0]
            else:
                pre_4 =[0, 0]
                
            c4=pre_4
            cells_4.append(c4)
            
    return cells_4

def count_combinations_4_cells(cells_4):
    count_c1 = 0
    count_c2 = 0
    count_un = 0

    total_count = len(cells_4) * 2

    for cell in cells_4:
        if cell.count(2) == 2:
            count_c1 += 2
        elif cell.count(2) == 1 and cell.count(1) == 1:
            count_c1 += 1
            count_c2 += 1
        elif cell.count(1) == 2:
            count_c2 += 2
        elif cell.count(2) == 1 and cell.count(0) == 1:
            count_c1 += 1
            count_un += 1
        elif cell.count(1) == 1 and cell.count(0) == 1:
            count_c2 += 1
            count_un += 1
        elif cell.count(0) == 2:
            count_un += 2
            
    probability_c1 = count_c1 / total_count
    probability_c2 = count_c2 / total_count
    probability_un = count_un / total_count

    return (
        probability_c1,
        probability_c2,
        probability_un
    )

def count_elements(lst):
    # Flatten the list
    flat_list = [item for sublist in lst for item in sublist]
    
    count_c1 = flat_list.count(2)
    count_c2 = flat_list.count(1)
    count_un = flat_list.count(0)
    
    total_count = count_c1 + count_c2 + count_un
    
    if total_count == 0:
        raise ValueError("The total count of elements is zero, cannot calculate probabilities.")
    
    probability_c1 = count_c1 / total_count
    probability_c2 = count_c2 / total_count
    probability_un = count_un / total_count
    
    return probability_c1, probability_c2, probability_un


def evaluate_difference(observed_probabilities, simulated_probabilities):
    difference = sum(abs(obs_prob - sim_prob) for obs_prob, sim_prob in zip(observed_probabilities, simulated_probabilities))
    return difference

def generate_positive_numbers(num_variables):
    # 生成 num_variables 个介于 0 到 1 之间的随机数
    numbers = [random.random() for _ in range(num_variables)]

    # 计算累加之和
    total_sum = sum(numbers)

    # 归一化，使得累加之和等于1
    normalized_numbers = [num / total_sum for num in numbers]

    return normalized_numbers


# 基于真实2细胞数据，等比例生成1000个细胞
cells_2 = [[2] for _ in range(550)] + [[1] for _ in range(440)] + [[0] for _ in range(10)]
#真实的4C比例，包括所有4C
true_lists = [[2] for _ in range(466)] + [[1] for _ in range(500)] + [[0] for _ in range(34)]

true_probabilities = count_elements(true_lists)
print(true_probabilities)
# Out:
# (0.466, 0.5, 0.034)

# %%
#IVF 模拟
import random
import numpy as np
from deap import base, creator, tools, algorithms
import matplotlib.pyplot as plt
import time

def evaluate_difference(observed_probabilities, simulated_probabilities):
    difference = sum(abs(obs_prob - sim_prob) for obs_prob, sim_prob in zip(observed_probabilities, simulated_probabilities))
    return difference

# 定义适应度评估函数
def evaluate_individual(individual):
    p1, p2, p3, p4,p5,p6,p7,p8,p9,p10,p11,p12,p13,p14,p15,p16,p17,p18 = individual
    sum1 = p1+p2+p3+p4+p5+p6
    sum2 = p7+p8+p9+p10+p11+p12
    sum3 = p13+p14+p15+p16+p17+p18
    p1 = p1/sum1
    p2 = p2/sum1
    p3 = p3/sum1
    p4 = p4/sum1
    p5 = p5/sum1
    p6 = p6/sum1
    p7 = p7/sum2
    p8 = p8/sum2
    p9 = p9/sum2
    p10 = p10/sum2
    p11 = p11/sum2
    p12 = p12/sum2
    p13 = p13/sum3
    p14 = p14/sum3
    p15 = p15/sum3
    p16 = p16/sum3
    p17 = p17/sum3
    p18 = p18/sum3
    # 如果任意一个参数小于0，则直接返回一个非常大的适应度值
    if any(p < 0 for p in [p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12, p13, p14, p15, p16, p17, p18]):
        difference=10
        return difference,
    else:
        simulated_cells_4 = simulate_cell_division(cells_2, p1, p2, p3, p4,p5,p7,p8,p9,p10,p11,p13,p14,p15,p16,p17)
        simulated_probabilities = count_combinations_4_cells(simulated_cells_4)
        difference = evaluate_difference(true_probabilities, simulated_probabilities)
        return difference,

# 定义遗传算法相关参数
population_size = 3200
num_generations = 200
num_parents = 1600
num_offspring = population_size - num_parents
num_repeats = 60

# 创建遗传算法工具箱
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))  # 通过使用负数的weights，我们可以建立最小化适应值的优化过程
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, 0, 1)  # 参数取值范围为[0, 1]
toolbox.register("individual", tools.initRepeat, creator.Individual, lambda: abs(random.uniform(0, 1)), n=18)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("evaluate", evaluate_individual)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=1, indpb=0.1)
toolbox.register("select", tools.selTournament, tournsize=3)

simulated_results = []  # 存储模拟结果
best_p_values = []  # 存储最佳p值

# 创建一个新的子图
#plt.figure(figsize=(5, 20))
best_fitnesses = []  # 存储每次迭代的最佳适应度值
# 迭代运行多次
for repeat in range(num_repeats):
    print(f"Repeat {repeat + 1}:")
    start_time = time.time()  # 记录模拟开始时间
    
    # 初始化种群
    population = toolbox.population(n=population_size)
    
    # 迭代演化
    for generation in range(num_generations):
        offspring = []
        
        # 通过选择父代个体、交叉操作和变异操作来生成指定数量的子代个体，并将其保存在子代列表中，以备后续的适应度评估和种群更新使用
        for _ in range(num_offspring):
            parent1 = random.choice(population)
            parent2 = random.choice(population)
            child = toolbox.clone(parent1)
            toolbox.mate(child, parent2)
            toolbox.mutate(child)
            offspring.append(child)
        
        # 评估子代适应度评，并将适应度值赋给相应的个体对象，以便进行后续的遗传算法操作。
        fitnesses = map(toolbox.evaluate, offspring)
        #print(toolbox.evaluate)
        for ind, fit in zip(offspring, fitnesses):
            ind.fitness.values = fit
        
        # 更新种群
        population = toolbox.select(population + offspring, k=population_size)
        # 存储每次迭代的最佳适应度值
        best_fitness = tools.selBest(population, k=1)[0].fitness.values[0]
        best_fitnesses.append(best_fitness) 
        
    # 获取最优解
    best_individual = tools.selBest(population, k=1)[0]
    best_p1, best_p2, best_p3, best_p4 , best_p5, best_p6, best_p7, best_p8, best_p9, best_p10, best_p11, best_p12, best_p13, best_p14, best_p15, best_p16, best_p17, best_p18= best_individual
    sum1 = best_p1+best_p2+best_p3+best_p4+best_p5+best_p6
    sum2 = best_p7+best_p8+best_p9+best_p10+best_p11+best_p12
    sum3 = best_p13+best_p14+best_p15+best_p16+best_p17+best_p18
    best_p1 = best_p1/sum1
    best_p2 = best_p2/sum1
    best_p3 = best_p3/sum1
    best_p4 = best_p4/sum1
    best_p5 = best_p5/sum1
    best_p6 = best_p6/sum1
    best_p7 = best_p7/sum2
    best_p8 = best_p8/sum2
    best_p9 = best_p9/sum2
    best_p10 = best_p10/sum2
    best_p11 = best_p11/sum2
    best_p12 = best_p12/sum2
    best_p13 = best_p13/sum3
    best_p14 = best_p14/sum3
    best_p15 = best_p15/sum3
    best_p16 = best_p16/sum3
    best_p17 = best_p17/sum3
    best_p18 = best_p18/sum3
    
    # 打印结果
    print("最佳p值:", best_p1, best_p2, best_p3, best_p4 , best_p5, best_p6, best_p7, best_p8, best_p9, best_p10, best_p11, best_p12, best_p13, best_p14, best_p15, best_p16, best_p17, best_p18)
    simulated_cells_4 = simulate_cell_division(cells_2, best_p1, best_p2, best_p3, best_p4,best_p5,best_p7,best_p8,best_p9,best_p10,best_p11,best_p13,best_p14,best_p15,best_p16,best_p17)
    simulated_probabilities = count_combinations_4_cells(simulated_cells_4)
    print("模拟结果:", simulated_probabilities)
    print("适应度:", tools.selBest(population, k=1)[0].fitness.values[0])
    print("diff:", evaluate_difference(true_probabilities, simulated_probabilities))
    
    end_time = time.time()  # 记录模拟结束时间
    elapsed_time = end_time - start_time  # 计算模拟运行时间
    elapsed_time_minutes = elapsed_time / 60  # 转换为分钟
    print("模拟用时", repeat + 1, ":", elapsed_time_minutes, "分钟")
    # 存储模拟结果和最佳p值
    simulated_results.append(simulated_probabilities)
    best_p_values.append([best_p1, best_p2, best_p3, best_p4])
    
    ## 绘制每次迭代的最佳适应度值变化曲线
    #plt.subplot(6, 1, repeat+1)  # 创建子图
    #best_fitnesses = [tools.selBest(population, k=1)[0].fitness.values[0] for population in populations]
    #plt.plot(range(num_generations), best_fitnesses, marker='o')
    #plt.xlabel('Generation')
    #plt.ylabel('Best Fitness')
    #plt.ylim(0, 0.2)  # 设置y轴范围
    #plt.title(f'Repeat {repeat+1}')
    #plt.grid(True)
    # 重置best_fitnesses列表，以便进行下一次迭代
    best_fitnesses = []

# 调整子图的间距
#plt.tight_layout()

# 显示所有子图
#plt.show()
# Out:
# Repeat 1:
# 最佳p值: 0.13496337916422446 0.6528717142680912 0.15250786790286347 0.004977612792406964 0.04985040544359235 0.004829020428821471 0.19771827548025478 0.09996610582300454 0.16625255784365436 0.07707960085061223 0.2125983610873189 0.24638509891515517 0.04944152366560201 0.033412815922769214 0.09126736321080223 0.5098756142560423 0.05163607981599888 0.2643666031287853
# 模拟结果: (0.4785, 0.49, 0.0315)
# 适应度: 0.0
# diff: 0.024999999999999967
# 模拟用时 1 : 12.702440134684245 分钟
# Repeat 2:
# 最佳p值: 0.07325799824778308 0.7871957012759325 0.10147197537616562 0.008880598814479028 0.013781886489244027 0.015411839796395738 0.13202356175865654 0.06884058681875752 0.003304548129513363 0.4344514758317763 0.11994894597355006 0.24143088148774625 0.05532352801646421 0.18226378508929064 0.3362514422510931 0.2255192353873343 0.16249203385492547 0.038149975400892204
# 模拟结果: (0.48, 0.487, 0.033)
# 适应度: 0.0
# diff: 0.02799999999999997
# 模拟用时 2 : 10.969505417346955 分钟
# Repeat 3:
# 最佳p值: 0.07422215973570379 0.7786201964784045 0.10889231852863288 0.015787749292529327 0.010803391053365339 0.011674184911364174 0.18294594922644639 0.002913318004886725 0.08153632332917714 0.18279627275779392 0.28362288319591183 0.266185253485784 0.19719200325653402 0.2715526658503577 0.054558227076542905 0.1825806742246794 0.15530972066505394 0.13880670892683206
# 模拟结果: (0.46, 0.505, 0.035)
# 适应度: 0.0
# diff: 0.01200000000000001
# 模拟用时 3 : 13.330856025218964 分钟
# Repeat 4:
# 最佳p值: 0.11397477846124116 0.6536817519826427 0.17416185097770548 0.028222090384211224 0.014274320469385838 0.01568520772481369 0.11710650373560248 0.2803037458834983 0.1576915738991303 0.31501048038825974 0.019475486221837507 0.11041220987167163 0.3745357916079066 0.140959812501021 0.19992160309782175 0.01662370683898501 0.0549153936199442 0.21304369233432138
# 模拟结果: (0.459, 0.492, 0.049)
# 适应度: 0.0
# diff: 0.030000000000000013
# 模拟用时 4 : 13.002720149358113 分钟
# Repeat 5:
# 最佳p值: 0.1612676425649537 0.5835776039198967 0.20311597702321144 0.017660902514839455 0.034115487997085324 0.000262385980013485 0.2974221492506677 0.07241465770029555 0.03142107061853752 0.20230459706872117 0.1807014762558529 0.21573604910592512 0.2435492068610966 0.12631406253683192 0.16702927159313297 0.2795534518471142 0.046134189644836635 0.13741981751698762
# 模拟结果: (0.4565, 0.5075, 0.036)
# 适应度: 0.0
# diff: 0.018999999999999954
# 模拟用时 5 : 10.874840080738068 分钟
# Repeat 6:
# 最佳p值: 0.24111797308160104 0.4565720359242006 0.2386207969158986 0.00026879043556570143 0.05336612768169553 0.01005427596103841 0.04809763973295041 0.3605141251540345 0.17104556753094147 0.10269470026153303 0.20093406742920966 0.11671389989133102 0.012268737080081166 0.19163021680898712 0.006209862187587003 0.11460870291949089 0.26039186901654326 0.4148906119873105
# 模拟结果: (0.4755, 0.4785, 0.046)
# 适应度: 0.0
# diff: 0.04299999999999997
# 模拟用时 6 : 14.033105544249217 分钟
# Repeat 7:
# 最佳p值: 0.12342226518444963 0.638535178786717 0.17681888873465945 0.047568234799653414 0.012800193519298116 0.0008552389752225967 0.21536005702515204 0.21606918259387797 0.024747301650268103 0.22951704430703476 0.08094497831607889 0.23336143610758822 0.05545584730608973 0.06544450062631502 0.07752862236504256 0.561249690915381 0.15719090883232492 0.08313042995484661
# 模拟结果: (0.4805, 0.4915, 0.028)
# 适应度: 0.0
# diff: 0.028999999999999967
# 模拟用时 7 : 11.486336346467336 分钟
# Repeat 8:
# 最佳p值: 0.08117993592501772 0.7459624612196818 0.11642783723247911 0.02724013494752002 0.024631774675732857 0.00455785599956872 0.26849925842426875 0.0016777471780563438 0.312777443398323 0.03894706885439727 0.23989365111766292 0.13820483102729184 0.07537108217494651 0.07582423770399219 0.41078933425996017 0.013157963609511842 0.4005852911795686 0.02427209107202072
# 模拟结果: (0.4645, 0.507, 0.0285)
# 适应度: 0.0
# diff: 0.014000000000000009
# 模拟用时 8 : 12.522619958718618 分钟
# Repeat 9:
# 最佳p值: 0.07945947808312995 0.7588458836794968 0.10044800401370278 0.011574951423147963 0.03930591697463192 0.010365765825890813 0.146352809080645 0.07394813520289412 0.24003865150654832 0.1922374349146402 0.11230025498848638 0.2351227143067861 0.05418728767306334 0.21660160219009217 0.20385804969666055 0.17666697466806003 0.1727332600495205 0.17595282572260348
# 模拟结果: (0.461, 0.4935, 0.0455)
# 适应度: 0.0
# diff: 0.023000000000000007
# 模拟用时 9 : 14.087154038747151 分钟
# Repeat 10:
# 最佳p值: 0.11186330702360595 0.6944701113825105 0.14244342022398818 0.019287177188063824 0.027044733434332544 0.004891250747498973 0.12247706037023436 0.22274976379391226 0.06497815477810284 0.22543961935077048 0.27360129105542813 0.09075411065155195 0.1794313983739135 0.22196468409774098 0.020213089120744758 0.22028714821897674 0.19964112839960213 0.158462551789022
# 模拟结果: (0.4815, 0.4875, 0.031)
# 适应度: 0.0
# diff: 0.030999999999999972
# 模拟用时 10 : 14.53044496377309 分钟
# Repeat 11:
# 最佳p值: 0.14040992414594672 0.6418256154748285 0.16484098081474358 0.022954157491736408 0.021412754408896218 0.008556567663848613 0.17676251329476203 0.045504276274554924 0.2632203101748567 0.2690732377215326 0.20183444388516378 0.04360521864913019 0.15449466756144786 0.13859001398092818 0.3298169874783899 0.11012667887039414 0.2331130733846235 0.033858578724216395
# 模拟结果: (0.4745, 0.4945, 0.031)
# 适应度: 0.0
# diff: 0.01699999999999996
# 模拟用时 11 : 12.282698277632395 分钟
# Repeat 12:
# 最佳p值: 0.0678920995974188 0.801016503364065 0.08610538590618594 0.001518711983735514 0.0417409209092207 0.0017263782393738534 0.02235364174489793 0.22370302531678163 0.22036390431897956 0.017065157390272836 0.08909044577529687 0.42742382545377133 0.21897887219077442 0.1903115766687548 0.09367450057840944 0.11172014000274404 0.25365851492947883 0.1316563956298385
# 模拟结果: (0.4655, 0.5125, 0.022)
# 适应度: 0.0
# diff: 0.02499999999999996
# 模拟用时 12 : 12.358171729246775 分钟
# Repeat 13:
# 最佳p值: 0.11387090038144104 0.7129128993234579 0.14209251407538814 0.01904406551118666 0.0010542279974617326 0.011025392711064575 0.1848391105594053 0.01647332141871588 0.2757068887509975 0.21280186567269369 0.09234161762348914 0.2178371959746984 0.2074495083979655 0.16045226414005165 0.10720364051357499 0.23476395165117692 0.23807533399647174 0.05205530130075925
# 模拟结果: (0.474, 0.501, 0.025)
# 适应度: 0.0
# diff: 0.017999999999999954
# 模拟用时 13 : 10.397511271635691 分钟
# Repeat 14:
# 最佳p值: 0.06924786181415499 0.7756007944817783 0.10223624958886861 0.038734362291902656 0.010308280521184817 0.0038724513021102234 0.22734259199487586 0.053538248623072285 0.18620516830299708 0.12792248719874244 0.0920275242853943 0.31296397959491806 0.12387619006069013 0.13637725206139165 0.20121236547074023 0.14837274290157756 0.17653137289205423 0.21363007661354613
# 模拟结果: (0.474, 0.4885, 0.0375)
# 适应度: 0.0
# diff: 0.022999999999999958
# 模拟用时 14 : 10.821361037095388 分钟
# Repeat 15:
# 最佳p值: 0.07364877315752218 0.7883635038446024 0.0797298146829136 0.002331732722137086 0.05075767175445172 0.0051685038383729506 0.12525088536907447 0.0584302296755313 0.22680258641073817 0.09374473411741482 0.3621533794032865 0.13361818502395476 0.29386476335285666 0.25304192992778934 0.07460052760219653 0.06142182701509354 0.1566061598886971 0.16046479221336693
# 模拟结果: (0.4715, 0.4945, 0.034)
# 适应度: 0.0
# diff: 0.010999999999999954
# 模拟用时 15 : 12.050084169705709 分钟
# Repeat 16:
# 最佳p值: 0.04628431312404798 0.821865845375737 0.08065582644023586 0.024332409696882547 0.0267559256770757 0.00010567968602088248 0.20178034459171232 0.22052821210564932 0.17751464546846182 0.14286251886625906 0.07631809024371991 0.18099618872419745 0.06892362368583406 0.22807631380303778 0.03431823154192477 0.2230873301006133 0.08916050376423927 0.3564339971043509
# 模拟结果: (0.455, 0.518, 0.027)
# 适应度: 0.0
# diff: 0.03600000000000003
# 模拟用时 16 : 12.181782162189483 分钟
# Repeat 17:
# 最佳p值: 0.10835389861624262 0.7113284565923059 0.13814912376027275 0.015562047380356717 0.005835232955525184 0.020771240695296796 0.24509751787192025 0.156708756454009 0.10630708473357557 0.13547386836228822 0.2603878442796293 0.09602492829857759 0.09820636481339673 0.27758679528796154 0.10423900780173025 0.09405027627231595 0.20771869154385822 0.21819886428073734
# 模拟结果: (0.474, 0.5005, 0.0255)
# 适应度: 0.0
# diff: 0.0169999999999999
# 模拟用时 17 : 12.555893981456757 分钟
# Repeat 18:
# 最佳p值: 0.08013943058005966 0.7514035368223076 0.11746103525953928 0.02964927189977789 0.007629560350931263 0.01371716508738434 0.037614332301267255 0.2770325251737934 0.20070447568818617 0.22283655880985087 0.13476696294492976 0.12704514508197262 0.47145430059420096 0.19820167196903105 0.1059571732999067 0.0983383189540691 0.125571686360575 0.0004768488222171943
# 模拟结果: (0.474, 0.4885, 0.0375)
# 适应度: 0.0
# diff: 0.022999999999999958
# 模拟用时 18 : 10.699271194140117 分钟
# Repeat 19:
# 最佳p值: 0.07738743323670834 0.7639373156112881 0.10705478249834154 0.018365667700480683 0.023099270811988856 0.01015553014119248 0.19455478933462494 0.1543087231420562 0.06441710467081434 0.22246896441976868 0.18815793302854766 0.17609248540418818 0.12359308926724547 0.0233809599326784 0.09671501808700286 0.49882950569293055 0.0944102790576642 0.16307114796247857
# 模拟结果: (0.4625, 0.503, 0.0345)
# 适应度: 0.0
# diff: 0.007000000000000006
# 模拟用时 19 : 13.255353446801504 分钟
# Repeat 20:
# 最佳p值: 0.06621339758314677 0.7638870388405711 0.10315740429385091 0.04732112733371215 0.01852538553685732 0.000895646411861732 0.09050561349630734 0.37363298701189723 0.10073132015030163 0.20313256569917126 0.14991147569856175 0.08208603794376076 0.3196828350362839 0.022235643670475213 0.039160669699477235 0.23436069260461664 0.15896980701463187 0.2255903519745151
# 模拟结果: (0.4665, 0.5065, 0.027)
# 适应度: 0.0
# diff: 0.013999999999999953
# 模拟用时 20 : 10.531594045956929 分钟
# Repeat 21:
# 最佳p值: 0.08060111791959979 0.7490977747674076 0.11169651385172676 0.01694774429568434 0.03126021534197374 0.010396633823608118 0.20511987715310498 0.09242200167365916 0.19298405157531767 0.07383388881824583 0.10647443970355244 0.3291657410761198 0.43862629092678296 0.03385678099582921 0.040606834213884925 0.23210186131949734 0.24126209094993886 0.013546141594066766
# 模拟结果: (0.462, 0.4995, 0.0385)
# 适应度: 0.0
# diff: 0.009000000000000001
# 模拟用时 21 : 14.963996013005575 分钟
# Repeat 22:
# 最佳p值: 0.1670993123656431 0.5996556380772583 0.1951985756097233 0.0056481208660550935 0.01957739799341141 0.012820955087908686 0.21722785997289562 0.18774256246855628 0.21143259741587422 0.019255276930019726 0.190112663933876 0.17422903927877811 0.273942426926209 0.17634112052579093 0.37579817566995916 0.04159604963199685 0.12220636758928854 0.010115859656755382
# 模拟结果: (0.451, 0.513, 0.036)
# 适应度: 0.0
# diff: 0.03000000000000002
# 模拟用时 22 : 14.263323764006296 分钟
# Repeat 23:
# 最佳p值: 0.08045383807777452 0.7796682904698312 0.08356300211439616 0.004186715636400707 0.04980683210147975 0.0023213216001177436 0.10010499419034442 0.15290952328551072 0.21064446930195255 0.029077171715222516 0.17387402039776692 0.3333898211092028 0.0904257215479513 0.30239814704176005 0.34023038222619756 0.08855332964223166 0.07390580575108091 0.10448661379077849
# 模拟结果: (0.463, 0.502, 0.035)
# 适应度: 0.0
# diff: 0.006000000000000005
# 模拟用时 23 : 15.544027523199718 分钟
# Repeat 24:
# 最佳p值: 0.09963156412662169 0.7146366050991602 0.12778304881007638 0.014797659286450448 0.024054172473123126 0.019096950204568062 0.05041834324651314 0.03326864125067764 0.24070682446432104 0.31081403280156406 0.12155874477007922 0.24323341346684496 0.16172623144281456 0.23791625311371434 0.2131252340792081 0.1669384328523025 0.16024445403076282 0.06004939448119765
# 模拟结果: (0.465, 0.4905, 0.0445)
# 适应度: 0.0
# diff: 0.021000000000000005
# 模拟用时 24 : 11.340933163960775 分钟
# Repeat 25:
# 最佳p值: 0.05297122810174027 0.803148151623033 0.09080327504773648 0.029506153163126818 0.017186732635772282 0.006384459428591207 0.10771885201136645 0.2519607076024136 0.22062847990565587 0.0645265310511452 0.10742299655324218 0.24774243287617664 0.06688335806628577 0.218112793458203 0.01935457039530775 0.41107844451992315 0.06261066720287968 0.22196016635740054
# 模拟结果: (0.4595, 0.508, 0.0325)
# 适应度: 0.0
# diff: 0.016000000000000014
# 模拟用时 25 : 12.521401258309682 分钟
# Repeat 26:
# 最佳p值: 0.13926166239358748 0.6556332256269848 0.14640390932558559 0.006507717664372418 0.0480895562334331 0.004103928756036719 0.1481558440610649 0.2088154738073302 0.2174257257910879 0.1107020446771437 0.15952253033845926 0.15537838132491405 0.22104334444673215 0.23576387969831414 0.24029798795257198 0.14455488319189913 0.029830200960920164 0.12850970374956236
# 模拟结果: (0.4675, 0.4955, 0.037)
# 适应度: 0.0
# diff: 0.009000000000000001
# 模拟用时 26 : 12.202274060249328 分钟
# Repeat 27:
# 最佳p值: 0.07558289151112699 0.7588656491977561 0.11353893510021476 0.018359669592787804 0.011697251091015359 0.021955603507099023 0.10996132327658832 0.2592233097129678 0.20337911527862207 0.17434010293004423 0.1266993915592022 0.12639675724257526 0.18999253967997976 0.08269403174293846 0.18616492395261228 0.14753644507591857 0.1851177903097155 0.20849426923883546
# 模拟结果: (0.4425, 0.502, 0.0555)
# 适应度: 0.0
# diff: 0.04700000000000002
# 模拟用时 27 : 12.36887336174647 分钟
# Repeat 28:
# 最佳p值: 0.11868423076946832 0.6640499536211372 0.1498329786049014 0.04550595963357137 0.018787357198248252 0.0031395201726733255 0.0452872425583566 0.4479680549929099 0.0620642025270591 0.10211235576060743 0.27549387560713556 0.06707426855393134 0.16542397463157582 0.08816564812356029 0.10070829931893394 0.04447116735563692 0.5070585565883214 0.09417235398197157
# 模拟结果: (0.479, 0.477, 0.044)
# 适应度: 0.0
# diff: 0.04599999999999997
# 模拟用时 28 : 10.044215285778046 分钟
# Repeat 29:
# 最佳p值: 0.07439469912251234 0.7881108505883153 0.0825835671914856 0.00851381472087178 0.03657551281088971 0.009821555565925176 0.11216899137627513 0.00457734580559811 0.597903076262371 0.13048495684925535 0.04896304911272556 0.1059025805937747 0.08666003008688752 0.3176530281367317 0.056614621974484164 0.29724602559063346 0.15205609764347666 0.08977019656778645
# 模拟结果: (0.476, 0.489, 0.035)
# 适应度: 0.0
# diff: 0.021999999999999964
# 模拟用时 29 : 11.120079183578492 分钟
# Repeat 30:
# 最佳p值: 0.11295115847979391 0.690409743573608 0.140848617813451 0.02236198972856485 0.024425039212353655 0.009003451192228574 0.2780487710795702 0.3472288258000725 0.010774351393926195 0.09843443067855535 0.2496336808302483 0.01587994021762724 0.09540033712736701 0.159187413056527 0.1418385086122438 0.2386519553128539 0.17545938390259344 0.18946240198841474
# 模拟结果: (0.4695, 0.503, 0.0275)
# 适应度: 0.0
# diff: 0.012999999999999953
# 模拟用时 30 : 11.40439650217692 分钟
# Repeat 31:
# 最佳p值: 0.07255484051363655 0.7664165070546616 0.12352666937480197 0.01998039900929605 0.004906057649135092 0.012615526398468862 0.08789456582263391 0.006961601332350634 0.10868878551287268 0.2910041713032412 0.2192189366954773 0.2862319393334243 0.14979894823415502 0.09216427386769249 0.3036907633470236 0.13481641997943558 0.2320161796697403 0.08751341490195291
# 模拟结果: (0.46, 0.5015, 0.0385)
# 适应度: 0.0
# diff: 0.011999999999999948
# 模拟用时 31 : 12.188517836729686 分钟
# Repeat 32:
# 最佳p值: 0.1430281665846301 0.6289415601807261 0.15636887928572699 0.02560296871502504 0.043300038226805296 0.002758387007086325 0.2994229916519184 0.18933652090603173 0.18332965403084478 0.003155948890728694 0.17383088564047963 0.15092399887999658 0.39153492785627414 0.00932853318369337 0.1529771608195559 0.18035382026959265 0.09035212301743015 0.17545343485345385
# 模拟结果: (0.4555, 0.506, 0.0385)
# 适应度: 0.0
# diff: 0.02100000000000001
# 模拟用时 32 : 8.67146404584249 分钟
# Repeat 33:
# 最佳p值: 0.13337807782817973 0.6436080981230123 0.17144407003645748 0.03578578260908479 0.009049403696278517 0.006734567706987066 0.020989250990763264 0.21534193823276476 0.23983430869643874 0.23867200136220973 0.13142167111845485 0.15374082959936863 0.03110326544911126 0.13881534020857905 0.10936598103997441 0.5219672476976975 0.05229621401497887 0.14645195158965882
# 模拟结果: (0.459, 0.508, 0.033)
# 适应度: 0.0
# diff: 0.016000000000000014
# 模拟用时 33 : 13.263824129104615 分钟
# Repeat 34:
# 最佳p值: 0.1118171273033682 0.7107094672568506 0.14353350791005287 0.020845239792489017 0.003754889124001701 0.009339768613237695 0.27385630880628176 0.2247389537742145 0.1233698501823812 0.19001497228733244 0.15507607937141663 0.03294383557837349 0.23292953641676428 0.11152164284449291 0.34829348480836686 0.028079129440244006 0.1763902167798191 0.10278598971031296
# 模拟结果: (0.4745, 0.499, 0.0265)
# 适应度: 0.0
# diff: 0.016999999999999956
# 模拟用时 34 : 8.990769191582997 分钟
# Repeat 35:
# 最佳p值: 0.06058342151797416 0.8063636844777976 0.08245330344500677 0.013260836368513964 0.019346939632153486 0.017991814558553875 0.31195249548918685 0.2458812604396898 0.1267695445664174 0.04419685123014844 0.0830086929705147 0.18819115530404268 0.5066128276026701 0.140873822380417 0.09395113105550539 0.13635511817869628 0.12128774318047753 0.000919357602233785
# 模拟结果: (0.466, 0.4965, 0.0375)
# 适应度: 0.0
# diff: 0.006999999999999999
# 模拟用时 35 : 12.51127599477768 分钟
# Repeat 36:
# 最佳p值: 0.05948486738072318 0.7960458466627772 0.07929579316677428 0.024392778167323062 0.035056006001566754 0.00572470862083543 0.2766996391469753 0.17274411834819103 0.2211435677737991 0.16987013889626257 0.14678966035447438 0.01275287548029744 0.2926888700944239 0.07464168931608253 0.13034028935326902 0.3421074642281441 0.1373105271589354 0.022911159849144998
# 模拟结果: (0.4685, 0.4895, 0.042)
# 适应度: 0.0
# diff: 0.02100000000000001
# 模拟用时 36 : 11.933702703317007 分钟
# Repeat 37:
# 最佳p值: 0.15812456612534687 0.6038206276612046 0.19013633069702807 0.033809768638000226 0.00866484963849512 0.00544385723992519 0.15001326611290547 0.21982811496712618 0.05132585776317394 0.3736652452561232 0.17833634127222506 0.026831174628446197 0.06696298704687723 0.31834438517505753 0.22423850144877566 0.1328987845241657 0.10250144818658662 0.15505389361853736
# 模拟结果: (0.464, 0.5035, 0.0325)
# 适应度: 0.0
# diff: 0.006999999999999951
# 模拟用时 37 : 10.912019085884094 分钟
# Repeat 38:
# 最佳p值: 0.05378084498782891 0.7800568434625594 0.0949888860114866 0.038173358500792745 0.03133798951191547 0.0016620775254166686 0.16786046869823995 0.2237265813083278 0.27325047885804765 0.18079633142576534 0.024810775938880276 0.12955536377073898 0.1918854850960213 0.09317658053821395 0.30349800531366206 0.0739050829314099 0.15436317110685988 0.18317167501383277
# 模拟结果: (0.4655, 0.501, 0.0335)
# 适应度: 0.0
# diff: 0.0020000000000000018
# 模拟用时 38 : 12.284384767214457 分钟
# Repeat 39:
# 最佳p值: 0.05471454479711193 0.8159295068301606 0.07652662759854148 0.012790912837197235 0.029981836384992296 0.010056571551996503 0.1626707111516366 0.16104314636075923 0.1461028884508789 0.12301159313426656 0.247125819501859 0.16004584140059988 0.3028882915649081 0.08741664905713666 0.06578659611057314 0.008983683877077124 0.08955877880077798 0.445366000589527
# 模拟结果: (0.4545, 0.5075, 0.038)
# 适应度: 0.0
# diff: 0.022999999999999958
# 模拟用时 39 : 11.410314921538035 分钟
# Repeat 40:
# 最佳p值: 0.09330638518820321 0.7320188674779781 0.13499927746740564 0.03604861106725123 0.002009161251622771 0.0016176975475390815 0.1775356624416997 0.17485637464284842 0.11114933307794309 0.028932161594034094 0.1459768558672492 0.3615496123762255 0.1439423596335756 0.17841135383119222 0.22565542288024157 0.2708981215446016 0.1541896496740954 0.026903092436293678
# 模拟结果: (0.4605, 0.5075, 0.032)
# 适应度: 0.0
# diff: 0.014999999999999958
# 模拟用时 40 : 9.362784051895142 分钟
# Repeat 41:
# 最佳p值: 0.09896559970030185 0.7069568003016319 0.1414589657723215 0.04243545743473212 0.010144166641889727 3.901014912284406e-05 0.20260114910004232 0.14994951941427434 0.33488672432736233 0.2577823150354983 0.02747827778939239 0.02730201433343033 0.047067155623711235 0.2099462810588326 0.24434599973691004 0.13742648408788846 0.14696039652970846 0.21425368296294925
# 模拟结果: (0.4625, 0.51, 0.0275)
# 适应度: 0.0
# diff: 0.020000000000000014
# 模拟用时 41 : 7.782927532990773 分钟
# Repeat 42:
# 最佳p值: 0.08893508097044256 0.7409345887979263 0.11078497969729774 0.010450772073696461 0.028782754546313655 0.020111823914323278 0.21452211253312337 0.2339988453285269 0.15413314910647366 0.10939238562657663 0.14400827810706615 0.14394522929823336 0.0902169594804798 0.1702928170939377 0.20337695271973116 0.2457093899695774 0.04265693271459049 0.24774694802168346
# 模拟结果: (0.469, 0.486, 0.045)
# 适应度: 0.0
# diff: 0.027999999999999955
# 模拟用时 42 : 4.09846096833547 分钟
# Repeat 43:
# 最佳p值: 0.050688046118202726 0.8261731189371887 0.0799205873544242 0.012115603008573348 0.021995001748795602 0.009107642832815368 0.1796238457715724 0.2135426705464601 0.10587670250176599 0.4130508324596151 0.05438597081885668 0.03351997790172979 0.21055780532871998 0.27452133978816723 0.12914276475466946 0.15900484622656838 0.21618401904695353 0.010589224854921362
# 模拟结果: (0.4705, 0.5045, 0.025)
# 适应度: 0.0
# diff: 0.017999999999999898
# 模拟用时 43 : 2.3997934182484943 分钟
# Repeat 44:
# 最佳p值: 0.15190777003922518 0.6520793444475225 0.1533217731605462 0.01356126473372012 0.020900147397810268 0.008229700221175739 0.20060437130697753 0.08946798463083884 0.22185611289372098 0.10409012971324078 0.2581264075932819 0.12585499386194007 0.22457798527862513 0.16273544600434547 0.20565569144001175 0.007784836102660714 0.14153729917035054 0.25770874200400645
# 模拟结果: (0.4835, 0.4885, 0.028)
# 适应度: 0.0
# diff: 0.034999999999999976
# 模拟用时 44 : 2.3734508554140725 分钟
# Repeat 45:
# 最佳p值: 0.1776333594048078 0.5171707497572607 0.2280393338459769 0.06036466430480653 0.015612258229617804 0.0011796344575300426 0.1777160525693239 0.2938289753061226 0.14101564130115285 0.11720013141390177 0.1535291853315481 0.11671001407795066 0.44606603638456516 0.1840037424418837 0.10877336340681645 0.06783833207509049 0.18119194130565888 0.012126584385985267
# 模拟结果: (0.463, 0.4875, 0.0495)
# 适应度: 0.0
# diff: 0.031000000000000014
# 模拟用时 45 : 2.438765903313955 分钟
# Repeat 46:
# 最佳p值: 0.060650327576543914 0.7624944678936048 0.12108193126373337 0.04560694050420407 0.00489208531851218 0.0052742474434017365 0.3395070082112573 0.29336353722737485 0.04628192980673743 0.22990238054009993 0.07439723008400524 0.016547914130525292 0.23174902287808163 0.2609635518083847 0.32224588302736046 0.051949750780588465 0.0638945123500322 0.0691972791555526
# 模拟结果: (0.465, 0.4995, 0.0355)
# 适应度: 0.0
# diff: 0.0029999999999999957
# 模拟用时 46 : 2.486859206358592 分钟
# Repeat 47:
# 最佳p值: 0.10614271908298512 0.7185184701996326 0.11221740770939016 0.012601233809995132 0.04544557410448107 0.005074595093515841 0.2605946302483949 0.14215307424623536 0.11900094538539346 0.21082500814829536 0.21436088198369632 0.05306545998798459 0.2241569772948971 0.2517913863040707 0.17710151304340077 0.0160062176725415 0.039377433917944994 0.29156647176714495
# 模拟结果: (0.472, 0.492, 0.036)
# 适应度: 0.0
# diff: 0.015999999999999952
# 模拟用时 47 : 2.475034228960673 分钟
# Repeat 48:
# 最佳p值: 0.05696517580183079 0.7581908849370143 0.09523632786032737 0.02634448915809212 0.053478212858022976 0.009784909384712468 0.46660682148413474 0.21371080040475615 0.001803592892556137 0.004659281521872626 0.0216858949914886 0.2915336087051918 0.2302153074893318 0.18654776834767184 0.14821750916813003 0.2556668116283046 0.03876893390399239 0.1405836694625694
# 模拟结果: (0.449, 0.4975, 0.0535)
# 适应度: 0.0
# diff: 0.039000000000000014
# 模拟用时 48 : 2.517383873462677 分钟
# Repeat 49:
# 最佳p值: 0.06815244949510423 0.7874304635314153 0.0891249531906822 0.008611104347581507 0.03762351850839252 0.009057510926824216 0.536644566671983 0.06440273727846506 0.0580265926914376 0.09779351305722767 0.2199607886602367 0.023171801640650157 0.06226719893385341 0.30923197432136845 0.10994150918294385 0.11790281275583646 0.13013182336336432 0.27052468144263353
# 模拟结果: (0.4705, 0.4985, 0.031)
# 适应度: 0.0
# diff: 0.008999999999999952
# 模拟用时 49 : 2.2320932745933533 分钟
# Repeat 50:
# 最佳p值: 0.12276103301900834 0.6537037829394453 0.15285650498372785 0.016805150084836427 0.05247008581401919 0.0014034431589630783 0.1317212942284483 0.15401827852468375 0.18105066894829364 0.1575859139536202 0.057379716261443066 0.31824412808351094 0.26849931402592025 0.02079828169812119 0.2793449728780821 0.024883960982780392 0.2167919394630836 0.1896815309520125
# 模拟结果: (0.4665, 0.502, 0.0315)
# 适应度: 0.0
# diff: 0.0050000000000000044
# 模拟用时 50 : 2.459630231062571 分钟
# Repeat 51:
# 最佳p值: 0.12097461667713201 0.6657617903722858 0.1529393836719349 0.008076763386104874 0.04982605337010523 0.0024213925224371284 0.2502714867549659 0.023806698877483407 0.2784376091616697 0.18893724335130807 0.10148993763257423 0.15705702422199863 0.14790347338640938 0.1957066933267854 0.32685050411849215 0.12416439263623766 0.19122315547340352 0.014151781058671799
# 模拟结果: (0.455, 0.51, 0.035)
# 适应度: 0.0
# diff: 0.02200000000000002
# 模拟用时 51 : 2.609791858990987 分钟
# Repeat 52:
# 最佳p值: 0.10025207074378367 0.6093799325152165 0.12127325019033695 0.034089230353940216 0.01846742483112706 0.11653809136559541 0.26152362816106905 0.07499340180693284 0.04060538302178799 0.16120020307147212 0.2210078463871081 0.24066953755162993 0.3986525618493556 0.05327115629718922 0.19177410871164707 0.05082885036891007 0.18066382102955716 0.12480950174334092
# 模拟结果: (0.425, 0.4185, 0.1565)
# 适应度: 0.0
# diff: 0.24500000000000005
# 模拟用时 52 : 2.4830955346425374 分钟
# Repeat 53:
# 最佳p值: 0.07924238945251218 0.753537681875842 0.10358932294686024 0.02130764511513001 0.02595251350942017 0.016370447100235188 0.24833625876690396 0.17190665514346387 0.2171748670378104 0.09377908430018787 0.14879664824524966 0.12000648650638436 0.1344237394073177 0.07226166675387773 0.03636301492540101 0.2612168365022131 0.10279091385393348 0.392943828557257
# 模拟结果: (0.472, 0.4975, 0.0305)
# 适应度: 0.0
# diff: 0.011999999999999955
# 模拟用时 53 : 2.553805716832479 分钟
# Repeat 54:
# 最佳p值: 0.3384714726686868 0.5556436418981302 0.03907584329834208 0.013243310851537531 0.025075142348429457 0.028490588934873964 0.27931580935209666 0.23134322239110205 0.005360042923997184 0.27272828036898045 0.1813326252559937 0.029920019707830106 0.2721736437985954 0.2438650852378906 0.17633310089582724 0.013296104815924345 0.2939303751186496 0.00040169013311283907
# 模拟结果: (0.6205, 0.327, 0.0525)
# 适应度: 0.0
# diff: 0.34600000000000003
# 模拟用时 54 : 2.5493926286697386 分钟
# Repeat 55:
# 最佳p值: 0.15568042225505765 0.6286135744542277 0.16065316496933704 0.0039053965843004164 0.05111111297673131 3.6328760346000586e-05 0.15111803334393395 0.3098559567991543 0.1397349267107489 0.1282435733941475 0.20278980926894632 0.06825770048306898 0.21432084060483933 0.09698758227191273 0.23404488681965066 0.042995330538655174 0.21479976456592545 0.1968515951990167
# 模拟结果: (0.4755, 0.495, 0.0295)
# 适应度: 0.0
# diff: 0.01899999999999996
# 模拟用时 55 : 2.574857739607493 分钟
# Repeat 56:
# 最佳p值: 0.06801474830247102 0.7971314989689371 0.07779346856309412 0.011359921744101345 0.03294726100816558 0.01275310141323084 0.12461752622389217 0.026341953338320484 0.2468466701384005 0.23168489815335735 0.06011395695720629 0.31039499518882324 0.17145253468272642 0.5049228840300358 0.18787228124524408 0.08830800628249026 0.023443482448129847 0.024000811311373514
# 模拟结果: (0.464, 0.5005, 0.0355)
# 适应度: 0.0
# diff: 0.003999999999999941
# 模拟用时 56 : 2.564426259199778 分钟
# Repeat 57:
# 最佳p值: 0.07412689027121179 0.7768375241893277 0.09648009250612123 0.013766695407573946 0.03447375986370314 0.004315037762062261 0.22566988510882188 0.09476539384401973 0.16832260179649178 0.33525642029102454 0.02250286293355056 0.15348283602609136 0.10354383340459679 0.1546832150367615 0.2153356191151907 0.12904040843497108 0.1454484908824735 0.2519484331260065
# 模拟结果: (0.4705, 0.4985, 0.031)
# 适应度: 0.0
# diff: 0.008999999999999952
# 模拟用时 57 : 2.5730838696161906 分钟
# Repeat 58:
# 最佳p值: 0.10716214177894061 0.7107266447823934 0.13865604325260933 0.015263080261033062 0.015806204180596865 0.012385885744426579 0.05942756712730341 0.0841266358291535 0.13323935682227314 0.09438170460648745 0.21343204914001546 0.415392686474767 0.05958405359653954 0.12317639126711247 0.347062574271908 0.14828837799188077 0.2684393819282974 0.05344922094426183
# 模拟结果: (0.47, 0.493, 0.037)
# 适应度: 0.0
# diff: 0.01399999999999995
# 模拟用时 58 : 2.5028494000434875 分钟
# Repeat 59:
# 最佳p值: 0.11426568765654872 0.5816396298059916 0.13475026198717804 0.14417394856350205 0.01925381292101439 0.005916659065765254 0.16424051497847192 0.14445010671214584 0.2009349736333717 0.09735505659771947 0.05246244060294404 0.3405569074753471 0.17853168957652896 0.027484320919451247 0.2574465801216411 0.09570637892649389 0.31563156769581124 0.12519946276007354
# 模拟结果: (0.467, 0.445, 0.088)
# 适应度: 0.0
# diff: 0.10999999999999999
# 模拟用时 59 : 2.6066492478052776 分钟
# Repeat 60:
# 最佳p值: 0.12089803800121778 0.6976132529377299 0.13133351551126096 0.021736496521482025 0.02820846632515552 0.0002102307031539312 0.20340935069397162 0.0235486817996446 0.24862421384313768 0.08626614409522852 0.2684045439373716 0.1697470656306461 0.09488717293625848 0.2349663436987976 0.2215077866680958 0.10094595658805659 0.2283692034305818 0.11932353667820973
# 模拟结果: (0.4755, 0.4995, 0.025)
# 适应度: 0.0
# diff: 0.018999999999999954
# 模拟用时 60 : 2.5984983801841737 分钟

# %%
#2024.8.26最新模拟，
#以单个细胞为单位，模拟2C发育到4C，用上所有数据，包括通过和没通过QC的细胞
#3代表 C1，2代表 C2，1代表 Undefined，0代表 
#PA模拟
import random
import time

def simulate_cell_division(cells, p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12, p13, p14, p15, p16, p17, p18, p19, p20, p21, p22, p23, p24, p25, p26, p27, p28, p29, p30, p31, p32, p33, p34, p35, p36, p37, p38, p39, p40):
    cells_4 = []
    for cell in cells:
        rand_num_1 = random.random()
        
        if cell == [3]:
            if rand_num_1 < p1:
                pre_4 =[3, 3]
            elif rand_num_1 < p1 + p2:
                pre_4 =[3, 2]
            elif rand_num_1 < p1 + p2 + p3:
                pre_4 =[2, 2]
            elif rand_num_1 < p1 + p2 + p3 + p4:
                pre_4 =[3, 1]
            elif rand_num_1 < p1 + p2 + p3 + p4 +p5:
                pre_4 =[3, 0]
            elif rand_num_1 < p1 + p2 + p3 + p4 +p5+p6:
                pre_4 =[2, 1]
            elif rand_num_1 < p1 + p2 + p3 + p4 +p5+p6+p7:
                pre_4 =[2, 0]
            elif rand_num_1 < p1 + p2 + p3 + p4 +p5+p6+p7+p8:
                pre_4 =[1, 1]
            elif rand_num_1 < p1 + p2 + p3 + p4 +p5+p6+p7+p8+p9:
                pre_4 =[1, 0]
            else:
                pre_4 =[0, 0]
                
            c4=pre_4
            cells_4.append(c4)
            
        elif cell == [2]:
            if rand_num_1 < p11:
                pre_4 =[3, 3]
            elif rand_num_1 < p11 + p12:
                pre_4 =[3, 2]
            elif rand_num_1 < p11 + p12 + p13:
                pre_4 =[2, 2]
            elif rand_num_1 < p11 + p12 + p13 + p14:
                pre_4 =[3, 1]
            elif rand_num_1 < p11 + p12 + p13 + p14 +p15:
                pre_4 =[3, 0]
            elif rand_num_1 < p11 + p12 + p13 + p14 +p15+p16:
                pre_4 =[2, 1]
            elif rand_num_1 < p11 + p12 + p13 + p14 +p15+p16+p17:
                pre_4 =[2, 0]
            elif rand_num_1 < p11 + p12 + p13 + p14 +p15+p16+p17+p18:
                pre_4 =[1, 1]
            elif rand_num_1 < p11 + p12 + p13 + p14 +p15+p16+p17+p18+p19:
                pre_4 =[1, 0]
            else:
                pre_4 =[0, 0]
                
            c4=pre_4
            cells_4.append(c4)
            
        elif cell == [1]:
            if rand_num_1 < p21:
                pre_4 =[3, 3]
            elif rand_num_1 < p21 + p22:
                pre_4 =[3, 2]
            elif rand_num_1 < p21 + p22 + p23:
                pre_4 =[2, 2]
            elif rand_num_1 < p21 + p22 + p23 + p24:
                pre_4 =[3, 1]
            elif rand_num_1 < p21 + p22 + p23 + p24 +p25:
                pre_4 =[3, 0]
            elif rand_num_1 < p21 + p22 + p23 + p24 +p25+p26:
                pre_4 =[2, 1]
            elif rand_num_1 < p21 + p22 + p23 + p24 +p25+p26+p27:
                pre_4 =[2, 0]
            elif rand_num_1 < p21 + p22 + p23 + p24 +p25+p26+p27+p28:
                pre_4 =[1, 1]
            elif rand_num_1 < p21 + p22 + p23 + p24 +p25+p26+p27+p28+p29:
                pre_4 =[1, 0]
            else:
                pre_4 =[0, 0]
                
            c4=pre_4
            cells_4.append(c4)
            
        elif cell == [0]:
            if rand_num_1 < p31:
                pre_4 =[3, 3]
            elif rand_num_1 < p31 + p32:
                pre_4 =[3, 2]
            elif rand_num_1 < p31 + p32 + p33:
                pre_4 =[2, 2]
            elif rand_num_1 < p31 + p32 + p33 + p34:
                pre_4 =[3, 1]
            elif rand_num_1 < p31 + p32 + p33 + p34 +p35:
                pre_4 =[3, 0]
            elif rand_num_1 < p31 + p32 + p33 + p34 +p35+p36:
                pre_4 =[2, 1]
            elif rand_num_1 < p31 + p32 + p33 + p34 +p35+p36+p37:
                pre_4 =[2, 0]
            elif rand_num_1 < p31 + p32 + p33 + p34 +p35+p36+p37+p38:
                pre_4 =[1, 1]
            elif rand_num_1 < p31 + p32 + p33 + p34 +p35+p36+p37+p38+p39:
                pre_4 =[1, 0]
            else:
                pre_4 =[0, 0]
                
            c4=pre_4
            cells_4.append(c4)
            
    return cells_4

def count_combinations_4_cells(cells_4):
    count_c1 = 0
    count_c2 = 0
    count_un = 0
    count_fqc = 0

    total_count = len(cells_4) * 2

    for cell in cells_4:
        if cell.count(3) == 2: 
            count_c1 += 2
        elif cell.count(3) == 1 and cell.count(2) == 1:
            count_c1 += 1
            count_c2 += 1
        elif cell.count(3) == 1 and cell.count(1) == 1:
            count_c1 += 1
            count_un += 1
        elif cell.count(3) == 1 and cell.count(0) == 1:
            count_c1 += 1
            count_fqc += 1
        elif cell.count(2) == 2:
            count_c2 += 2
        elif cell.count(2) == 1 and cell.count(1) == 1:
            count_c2 += 1
            count_un += 1
        elif cell.count(2) == 1 and cell.count(0) == 1:
            count_c2 += 1
            count_fqc += 1
        elif cell.count(1) == 2:
            count_un += 2
        elif cell.count(1) == 1 and cell.count(0) == 1:
            count_un += 1
            count_fqc += 1
        elif cell.count(0) == 2:
            count_fqc += 2
            
    probability_c1 = count_c1 / total_count
    probability_c2 = count_c2 / total_count
    probability_un = count_un / total_count
    probability_fqc = count_fqc / total_count

    return (
        probability_c1,
        probability_c2,
        probability_un,
        probability_fqc
    )

def count_elements(lst):
    # Flatten the list
    flat_list = [item for sublist in lst for item in sublist]
    
    count_c1 = flat_list.count(3)
    count_c2 = flat_list.count(2)
    count_un = flat_list.count(1)
    count_fqc = flat_list.count(0)
    
    total_count = count_c1 + count_c2 + count_un+count_fqc
    
    if total_count == 0:
        raise ValueError("The total count of elements is zero, cannot calculate probabilities.")
    
    probability_c1 = count_c1 / total_count
    probability_c2 = count_c2 / total_count
    probability_un = count_un / total_count
    probability_fqc = count_fqc / total_count
    
    return probability_c1, probability_c2, probability_un,probability_fqc


def evaluate_difference(observed_probabilities, simulated_probabilities):
    difference = sum(abs(obs_prob - sim_prob) for obs_prob, sim_prob in zip(observed_probabilities, simulated_probabilities))
    return difference

def generate_positive_numbers(num_variables):
    # 生成 num_variables 个介于 0 到 1 之间的随机数
    numbers = [random.random() for _ in range(num_variables)]

    # 计算累加之和
    total_sum = sum(numbers)

    # 归一化，使得累加之和等于1
    normalized_numbers = [num / total_sum for num in numbers]

    return normalized_numbers

# 基于真实2细胞数据，等比例生成1000个细胞
cells_2 = [[3] for _ in range(248)]+[[2] for _ in range(158)] + [[1] for _ in range(51)] + [[0] for _ in range(543)]
#真实的4C比例，包括所有4C
true_lists = [[3] for _ in range(314)]+[[2] for _ in range(254)] + [[1] for _ in range(6)] + [[0] for _ in range(426)]

true_probabilities = count_elements(true_lists)
print(true_probabilities)
# Out:
# (0.314, 0.254, 0.006, 0.426)

# %%
#以单个细胞为单位，模拟2C发育到4C，用上所有数据，包括通过和没通过QC的细胞
#3代表 C1，2代表 C2，1代表 Undefined，0代表 
#PA模拟
import random
import numpy as np
from deap import base, creator, tools, algorithms
import matplotlib.pyplot as plt
import time

def custom_mutate(individual, mu=0, sigma=1, indpb=0.1):
    for i in range(len(individual)):
        if random.random() < indpb:
            individual[i] += random.gauss(mu, sigma)
            individual[i] = abs(individual[i])
            
def evaluate_difference(observed_probabilities, simulated_probabilities):
    difference = sum(abs(obs_prob - sim_prob) for obs_prob, sim_prob in zip(observed_probabilities, simulated_probabilities))
    return difference

# 定义适应度评估函数
def evaluate_individual(individual):
            
    p1, p2, p3, p4, p5, p6, p7, p8, p9, p10,p11, p12, p13, p14, p15, p16, p17, p18, p19, p20,p21, p22, p23, p24, p25, p26, p27, p28, p29, p30,p31, p32, p33, p34, p35, p36, p37, p38, p39, p40 = individual
    sum1 = p1+ p2+ p3+ p4+ p5+ p6+ p7+ p8+ p9+ p10
    sum2 = p11+ p12+ p13+ p14+ p15+ p16+ p17+ p18+ p19+ p20
    sum3 = p21+ p22+ p23+ p24+ p25+ p26+ p27+ p28+ p29+ p30
    sum4 = p31+ p32+ p33+ p34+ p35+ p36+ p37+ p38+ p39+ p40
    p1 = p1 / sum1
    p2 = p2 / sum1
    p3 = p3 / sum1
    p4 = p4 / sum1
    p5 = p5 / sum1
    p6 = p6 / sum1
    p7 = p7 / sum1
    p8 = p8 / sum1
    p9 = p9 / sum1
    p10 = p10 / sum1
    p11 = p11 / sum2
    p12 = p12 / sum2
    p13 = p13 / sum2
    p14 = p14 / sum2
    p15 = p15 / sum2
    p16 = p16 / sum2
    p17 = p17 / sum2
    p18 = p18 / sum2
    p19 = p19 / sum2
    p20 = p20 / sum2
    p21 = p21 / sum3
    p22 = p22 / sum3
    p23 = p23 / sum3
    p24 = p24 / sum3
    p25 = p25 / sum3
    p26 = p26 / sum3
    p27 = p27 / sum3
    p28 = p28 / sum3
    p29 = p29 / sum3
    p30 = p30 / sum3
    p31 = p31 / sum4
    p32 = p32 / sum4
    p33 = p33 / sum4
    p34 = p34 / sum4
    p35 = p35 / sum4
    p36 = p36 / sum4
    p37 = p37 / sum4
    p38 = p38 / sum4
    p39 = p39 / sum4
    p40 = p40 / sum4

    #明天从这里继续修改
    
    # 如果任意一个参数小于0，则直接返回一个非常大的适应度值
    if any(p < 0 for p in [p1, p2, p3, p4, p5, p6, p7, p8, p9, p10,p11, p12, p13, p14, p15, p16, p17, p18, p19, p20,p21, p22, p23, p24, p25, p26, p27, p28, p29, p30,p31, p32, p33, p34, p35, p36, p37, p38, p39, p40]):
        difference=10
        return difference,
    else:
        simulated_cells_4 = simulate_cell_division(cells_2, p1, p2, p3, p4, p5, p6, p7, p8, p9, p10,p11, p12, p13, p14, p15, p16, p17, p18, p19, p20,p21, p22, p23, p24, p25, p26, p27, p28, p29, p30,p31, p32, p33, p34, p35, p36, p37, p38, p39, p40)
        simulated_probabilities = count_combinations_4_cells(simulated_cells_4)
        difference = evaluate_difference(true_probabilities, simulated_probabilities)
        return difference,

# 定义遗传算法相关参数
population_size = 3200
num_generations = 200
num_parents = 1600
num_offspring = population_size - num_parents
num_repeats = 50

# 创建遗传算法工具箱
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))  # 通过使用负数的weights，我们可以建立最小化适应值的优化过程
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, 0, 1)  # 参数取值范围为[0, 1]
toolbox.register("individual", tools.initRepeat, creator.Individual, lambda: abs(random.uniform(0, 1)), n=40)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("evaluate", evaluate_individual)
toolbox.register("mate", tools.cxTwoPoint)
#原始的突变，可能会突变出负数
#toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=1, indpb=0.1)
toolbox.register("mutate", custom_mutate, mu=0, sigma=1, indpb=0.1)
toolbox.register("select", tools.selTournament, tournsize=3)

simulated_results = []  # 存储模拟结果
best_p_values = []  # 存储最佳p值

# 创建一个新的子图
#plt.figure(figsize=(5, 20))
best_fitnesses = []  # 存储每次迭代的最佳适应度值
# 迭代运行多次
for repeat in range(num_repeats):
    print(f"Repeat {repeat + 1}:")
    start_time = time.time()  # 记录模拟开始时间
    
    # 初始化种群
    population = toolbox.population(n=population_size)
    
    # 迭代演化
    for generation in range(num_generations):
        offspring = []
        
        # 通过选择父代个体、交叉操作和变异操作来生成指定数量的子代个体，并将其保存在子代列表中，以备后续的适应度评估和种群更新使用
        for _ in range(num_offspring):
            parent1 = random.choice(population)
            parent2 = random.choice(population)
            child = toolbox.clone(parent1)
            toolbox.mate(child, parent2)
            toolbox.mutate(child)
            #child = [abs(x) for x in child]#突变后会产生负数，将负数替换为其相反数
            offspring.append(child)
        
        # 评估子代适应度评，并将适应度值赋给相应的个体对象，以便进行后续的遗传算法操作。
        fitnesses = map(toolbox.evaluate, offspring)
        #print(toolbox.evaluate)
        for ind, fit in zip(offspring, fitnesses):
            ind.fitness.values = fit
        
        # 更新种群
        population = toolbox.select(population + offspring, k=population_size)
        # 存储每次迭代的最佳适应度值
        best_fitness = tools.selBest(population, k=1)[0].fitness.values[0]
        best_fitnesses.append(best_fitness) 
        
    # 获取最优解
    best_individual = tools.selBest(population, k=1)[0]
    best_p1, best_p2, best_p3, best_p4, best_p5, best_p6, best_p7, best_p8, best_p9, best_p10, best_p11, best_p12, best_p13, best_p14, best_p15, best_p16, best_p17, best_p18, best_p19, best_p20, best_p21, best_p22, best_p23, best_p24, best_p25, best_p26, best_p27, best_p28, best_p29, best_p30, best_p31, best_p32, best_p33, best_p34, best_p35, best_p36, best_p37, best_p38, best_p39, best_p40= best_individual
    
    sum1 = best_p1 + best_p2 + best_p3 + best_p4 + best_p5 + best_p6 + best_p7 + best_p8 + best_p9 + best_p10
    sum2 = best_p11 + best_p12 + best_p13 + best_p14 + best_p15 + best_p16 + best_p17 + best_p18 + best_p19 + best_p20
    sum3 = best_p21 + best_p22 + best_p23 + best_p24 + best_p25 + best_p26 + best_p27 + best_p28 + best_p29 + best_p30
    sum4 = best_p31 + best_p32 + best_p33 + best_p34 + best_p35 + best_p36 + best_p37 + best_p38 + best_p39 + best_p40

    best_p1 = best_p1 / sum1
    best_p2 = best_p2 / sum1
    best_p3 = best_p3 / sum1
    best_p4 = best_p4 / sum1
    best_p5 = best_p5 / sum1
    best_p6 = best_p6 / sum1
    best_p7 = best_p7 / sum1
    best_p8 = best_p8 / sum1
    best_p9 = best_p9 / sum1
    best_p10 = best_p10 / sum1
    best_p11 = best_p11 / sum2
    best_p12 = best_p12 / sum2
    best_p13 = best_p13 / sum2
    best_p14 = best_p14 / sum2
    best_p15 = best_p15 / sum2
    best_p16 = best_p16 / sum2
    best_p17 = best_p17 / sum2
    best_p18 = best_p18 / sum2
    best_p19 = best_p19 / sum2
    best_p20 = best_p20 / sum2
    best_p21 = best_p21 / sum3
    best_p22 = best_p22 / sum3
    best_p23 = best_p23 / sum3
    best_p24 = best_p24 / sum3
    best_p25 = best_p25 / sum3
    best_p26 = best_p26 / sum3
    best_p27 = best_p27 / sum3
    best_p28 = best_p28 / sum3
    best_p29 = best_p29 / sum3
    best_p30 = best_p30 / sum3
    best_p31 = best_p31 / sum4
    best_p32 = best_p32 / sum4
    best_p33 = best_p33 / sum4
    best_p34 = best_p34 / sum4
    best_p35 = best_p35 / sum4
    best_p36 = best_p36 / sum4
    best_p37 = best_p37 / sum4
    best_p38 = best_p38 / sum4
    best_p39 = best_p39 / sum4
    best_p40 = best_p40 / sum4

    # 打印结果
    print("最佳p值:", best_p1, best_p2, best_p3, best_p4, best_p5, best_p6, best_p7, best_p8, best_p9, best_p10, best_p11, best_p12, best_p13, best_p14, best_p15, best_p16, best_p17, best_p18, best_p19, best_p20, best_p21, best_p22, best_p23, best_p24, best_p25, best_p26, best_p27, best_p28, best_p29, best_p30, best_p31, best_p32, best_p33, best_p34, best_p35, best_p36, best_p37, best_p38, best_p39, best_p40)
    simulated_cells_4 = simulate_cell_division(cells_2, best_p1, best_p2, best_p3, best_p4, best_p5, best_p6, best_p7, best_p8, best_p9, best_p10, best_p11, best_p12, best_p13, best_p14, best_p15, best_p16, best_p17, best_p18, best_p19, best_p20, best_p21, best_p22, best_p23, best_p24, best_p25, best_p26, best_p27, best_p28, best_p29, best_p30, best_p31, best_p32, best_p33, best_p34, best_p35, best_p36, best_p37, best_p38, best_p39, best_p40)
    simulated_probabilities = count_combinations_4_cells(simulated_cells_4)
    print("模拟结果:", simulated_probabilities)
    print("适应度:", tools.selBest(population, k=1)[0].fitness.values[0])
    print("diff:", evaluate_difference(true_probabilities, simulated_probabilities))
    
    end_time = time.time()  # 记录模拟结束时间
    elapsed_time = end_time - start_time  # 计算模拟运行时间
    elapsed_time_minutes = elapsed_time / 60  # 转换为分钟
    print("模拟用时", repeat + 1, ":", elapsed_time_minutes, "分钟")
    # 存储模拟结果和最佳p值
    simulated_results.append(simulated_probabilities)
    best_p_values.append([best_p1, best_p2, best_p3, best_p4, best_p5, best_p6, best_p7, best_p8, best_p9, best_p10, best_p11, best_p12, best_p13, best_p14, best_p15, best_p16, best_p17, best_p18, best_p19, best_p20, best_p21, best_p22, best_p23, best_p24, best_p25, best_p26, best_p27, best_p28, best_p29, best_p30, best_p31, best_p32, best_p33, best_p34, best_p35, best_p36, best_p37, best_p38, best_p39, best_p40])
    
    best_fitnesses = []
# Out:
# Repeat 1:
# 最佳p值: 0.06944180147281703 0.030603202128756214 0.12454621799003135 0.06917078331243377 0.1589660215729622 0.01612284233025439 0.15498436185973063 0.009602928187463791 0.005127904154088246 0.3614339369914623 0.07537580962446476 0.2195045559773951 0.18547877596404622 0.03062212091236075 0.149801495652956 0.043978987760096386 0.1667724494153775 0.0017062557617649452 0.006529084792722826 0.1202304641388155 0.14325232416347639 0.3130027697424143 0.05780892634040606 0.07875447491518572 0.038996463985666786 0.10952343392874277 0.0397030102572965 0.05884834781268012 0.07072071196607847 0.08938953688805276 0.18516786144705774 0.08133026730207218 0.02892280435075527 0.008896147106020035 0.2129566638795863 0.008914771990892816 0.19834397745795543 0.01805516998129561 0.002926456274623849 0.25448588020974067
# 模拟结果: (0.2945, 0.239, 0.0385, 0.428)
# 适应度: 0.015000000000000006
# diff: 0.06900000000000003
# 模拟用时 1 : 7.609935164451599 分钟
# Repeat 2:
# 最佳p值: 0.10368573790574952 0.09072209976726277 0.027461469780982475 0.01622242883192227 0.3265486487354931 0.023183566127349717 0.19700617203074497 0.0024592672348510633 0.008658015046799025 0.20405259453884522 0.11669280568650188 0.11229756206024352 0.23243749649853537 0.0022179652397685307 0.1819984278031871 0.015269527882482136 0.2841127217705588 0.008323072420412088 0.019251520560987074 0.02739890007732349 0.02036595145856631 0.10865124923824256 0.1944016524200144 0.05049184594826328 0.23432441277676128 0.10093079302798744 0.2085711639566314 0.04630384265641448 0.014918024700059124 0.02104106381705969 0.05412806831551736 0.16670887783736987 0.06221720439910859 0.012559405760921589 0.3340362008163594 0.01229778712230593 0.18837861392281344 0.008326954153919744 0.0034689667336185634 0.15787792093806538
# 模拟结果: (0.31, 0.2655, 0.0305, 0.394)
# 适应度: 0.013000000000000006
# diff: 0.07199999999999998
# 模拟用时 2 : 7.4927162528038025 分钟
# Repeat 3:
# 最佳p值: 0.009259954226036279 0.1568399619316333 0.11328014874062017 0.02196685599200576 0.3281087256666605 0.05292224248471177 0.09467363242307121 0.012611710542197466 0.003607791169521721 0.2067289768235417 0.2416678146285426 0.05073271854570776 0.17884914496360801 0.0016735253803941035 0.2493561895399647 0.010975478724432794 0.13837998399772347 0.03330819194714414 0.0044761531638080245 0.09058079910867449 0.24569300258326568 0.09324146368778859 0.08535173552360574 0.04909080268172809 0.21769054955279696 0.001651023864972957 0.21929259791310285 0.030458562626379443 0.05544432194761925 0.0020859396187405082 0.20301607432039934 0.10220624937079115 0.05945280028499661 0.004703734571745 0.10220104423723961 0.0037428283060658572 0.2099663550493288 0.0017438007745058603 0.010914445613800346 0.3020526674711274
# 模拟结果: (0.312, 0.2485, 0.0295, 0.41)
# 适应度: 0.014000000000000005
# diff: 0.04700000000000002
# 模拟用时 3 : 7.44253758986791 分钟
# Repeat 4:
# 最佳p值: 0.0395010585515297 0.053160825111739564 0.04227944029850457 0.012851636375444566 0.4989491416302606 0.04145942047371646 0.24854798789291588 0.002003158297337593 0.03275275957606127 0.02849457179248973 0.27514545212688446 0.14218889098288326 0.10387477314694554 0.012490398049013352 0.01697228839184758 0.00854320288183655 0.2217454969221953 0.0032437524225398884 0.025667174216088877 0.19012857085976534 0.1194711051119501 0.1065033317049682 0.06288134551300292 0.013783621034784777 0.20863139065011532 0.044586880441220535 0.2646853776987309 0.048015890809359786 0.015720364177923534 0.11572069285794383 0.041176321490204504 0.05086496935768397 0.09485201950037667 0.004428416617860883 0.3783092572496405 0.0023954213476129554 0.26482228439797656 0.0034472931952968596 0.0158868406055414 0.14381717623780546
# 模拟结果: (0.296, 0.245, 0.026, 0.433)
# 适应度: 0.017000000000000008
# diff: 0.05400000000000003
# 模拟用时 4 : 7.500176922480265 分钟
# Repeat 5:
# 最佳p值: 0.10940127076376606 0.12113097332685756 0.10910281976845433 0.04858011107693762 0.29297805147253964 0.02927591154571225 0.22443710984553777 0.011583966070652341 0.0004035646821213533 0.05310622144742117 0.05087819930681365 0.04076976772676762 0.1727965826106943 0.026320735978371278 0.2643867898675657 0.013361204589956677 0.17487235386203334 0.0015368151371859763 0.002672702407554542 0.25240484851305695 0.05129209184133318 0.1819373615092443 0.0020324275572247276 0.03440253283596191 0.11890091247023742 0.10891907525146471 0.28476527519196676 0.0038065395322869687 0.10247762275934726 0.11146616105093282 0.11808882952847782 0.1498948317825071 0.05258441422056845 0.004547680471865842 0.14949865268572882 0.01947386614463612 0.23219639543504872 0.00024971977217548894 0.011963667847691215 0.26150194211130046
# 模拟结果: (0.287, 0.244, 0.0355, 0.4335)
# 适应度: 0.012000000000000005
# diff: 0.07400000000000004
# 模拟用时 5 : 7.593990182876587 分钟
# Repeat 6:
# 最佳p值: 0.0887395120058722 0.034511123431371034 0.08065355151748979 0.029390780946749955 0.2470622873248036 0.01562644679399038 0.26107900100221093 0.009690536812486565 0.03853392928004156 0.1947128308849841 0.20898629214457085 0.07899451392507058 0.2133609041833692 0.029173066184970998 0.08486920182710224 0.04006928364450784 0.09176291239090427 0.02073849104524442 0.008807011480885203 0.22323832317337444 0.2359874120163259 0.026736991008538415 0.22662925793765712 0.006925119509674853 0.08848457213227061 0.14314522076141536 0.018001642239753347 0.05379327523453886 0.0234797812557568 0.17681672790406866 0.1358395821751299 0.08656511057161216 0.12017739989346679 0.0028965806885086834 0.2464493619010872 0.007059369743483105 0.17308042817231478 0.008708749468468769 0.0102592276887878 0.208964189697141
# 模拟结果: (0.292, 0.264, 0.0515, 0.3925)
# 适应度: 0.02000000000000001
# diff: 0.111
# 模拟用时 6 : 7.540309286117553 分钟
# Repeat 7:
# 最佳p值: 0.20474926616865174 0.016024811534983266 0.028738460053404535 0.03124256699148539 0.29091154363448085 0.016578342127997633 0.17435903185163734 0.03594472200590008 0.00018487132331728267 0.2012663843081417 0.09713602039697501 0.019801493289667335 0.20385770601829253 0.06375466696135983 0.30990562390113185 0.06542590421568024 0.09245799380643845 0.011687067756624994 0.020592348294989817 0.11538117535884013 0.03351563295271993 0.21369842299090352 0.19091329770011328 0.09955881601435457 0.014462595980874904 0.05344666206368673 0.19959592876010546 0.034619847162764304 0.09974972920391918 0.06043906717055815 0.08570343671518953 0.06153423424781418 0.1366663871516462 0.015816798323686678 0.2783030497061828 0.006651177417162077 0.18961169409741022 0.0015488948077934535 0.0018608579237757157 0.2223034696093392
# 模拟结果: (0.2975, 0.244, 0.042, 0.4165)
# 适应度: 0.013000000000000006
# diff: 0.07200000000000004
# 模拟用时 7 : 7.535984639326731 分钟
# Repeat 8:
# 最佳p值: 0.015587643864991521 0.16093865605062277 0.0904979677185076 0.002264080622257317 0.12025968457762601 0.05580349141282353 0.24964160207254524 0.0007536037407886125 0.03253445787151834 0.271718812068319 0.16233798133004002 0.13984899840842394 0.10265577725749862 0.022000966101576425 0.26761774982037384 0.0034217374566107746 0.17272514471503875 0.02528430486885448 0.01741007351792761 0.08669726652365563 0.25069421714586776 0.24507697808346465 0.013015146582886756 0.011924821429249027 0.1346938155766803 0.028566352543236223 0.09183932067089232 0.08057057647944199 0.03810950415599049 0.10550926733229035 0.06820958988142722 0.12856946984729167 0.006090854836571541 0.0224228058922696 0.34364713257222523 0.0021158638997429984 0.24451528941410727 0.0008902794905931068 0.006233424087729423 0.17730529007804202
# 模拟结果: (0.2975, 0.219, 0.0295, 0.454)
# 适应度: 0.0050000000000000044
# diff: 0.10300000000000004
# 模拟用时 8 : 7.506540739536286 分钟
# Repeat 9:
# 最佳p值: 0.010153804661043086 0.1804414000241086 0.09718339221606796 0.04872990560203708 0.2512676585824305 0.02326595507981398 0.0918370064201704 5.2757297306392257e-05 0.004051176753368787 0.29301694336365325 0.23335046635053555 0.18946263462659674 0.11164246210708753 0.03372014107907197 0.057125791333916126 0.017476725298130956 0.031789473595390354 0.0037995890015700834 0.005655313657564903 0.31597740295013543 0.033635919671360974 0.14827273883445136 0.09586832963120641 0.01775073299663631 0.08802481185994093 0.014148028445026979 0.22516532724768312 0.04562942823807628 0.0549666721209575 0.27653801095466013 0.07944447909559921 0.16638643324478056 0.009523023372656472 0.0017810210924831577 0.41066298532059653 0.0012587477251915188 0.2834642598031385 0.003477849880470217 0.0014790184868879528 0.04252218197819583
# 模拟结果: (0.315, 0.2655, 0.0215, 0.398)
# 适应度: 0.005000000000000003
# diff: 0.05599999999999998
# 模拟用时 9 : 7.6073947509129844 分钟
# Repeat 10:
# 最佳p值: 0.09675129300293643 0.10047673120894315 0.1410637457109406 0.011809427468753554 0.19383946237054608 0.022902942237733738 0.1426521142193691 0.01253186183665747 0.018986079718550094 0.25898634222556977 0.20984176307097238 0.19461348402468884 0.21798923697941336 0.010357081319994452 0.134821608274524 0.013877090250349163 0.05940242317877943 0.001432105206953992 0.008626690025926054 0.14903851766839826 0.12867715548260047 0.11708413539277097 0.053407248476987614 0.028009518103082987 0.31516317494511487 0.03901591420291863 0.05735497190847004 0.008306193961408056 0.1094955350995966 0.14348615242704976 0.029731043395738475 0.023528984200526237 0.10773601576009889 0.01174973770800958 0.486026630381125 0.00798681042515893 0.15405981392152565 0.0006526073473656001 0.04265290239857058 0.13587545446188115
# 模拟结果: (0.2825, 0.259, 0.0375, 0.421)
# 适应度: 0.010000000000000004
# diff: 0.07300000000000004
# 模拟用时 10 : 7.505380280812582 分钟
# Repeat 11:
# 最佳p值: 0.03631369621231346 0.18011767849735633 0.07038141819366303 0.04392216337408899 0.19107518982995741 0.0076364475780028515 0.24804056833796906 0.01940025393210229 0.03838649074553364 0.1647260932990129 0.057645393280108925 0.031335150803617436 0.2108590627685319 0.03880487840921661 0.09604901109195066 0.09851710357506933 0.1841324410612851 0.0006092175170890792 0.03991912993159277 0.24212861156153812 0.1396410915968768 0.040954842748217236 0.18821097731545716 0.04528790522786548 0.016148984798184964 0.008937269483034424 0.1951336494001966 0.07035919084857009 0.0309707268558551 0.2643553617257421 0.12765436836677102 0.07742772307329407 0.0571575028235831 0.0018164026528743244 0.35952502268179876 0.002558669850256588 0.053257113034731 0.0035883540699511714 0.053182691937839074 0.26383215150890094
# 模拟结果: (0.297, 0.207, 0.056, 0.44)
# 适应度: 0.01800000000000001
# diff: 0.12800000000000006
# 模拟用时 11 : 7.532103725274404 分钟
# Repeat 12:
# 最佳p值: 0.02357892153262431 0.10235945514162771 0.18135294810389607 0.005890051947092614 0.16046564975681168 0.056185753455800895 0.1362632748988833 0.012953015090719765 0.003028145221876037 0.3179227848506676 0.12004607630219867 0.20774598684472592 0.17481866136326565 0.0033951151617945497 0.1310125432724224 0.008322134838755397 0.2527408753253408 0.0283650187317606 0.028654239006121844 0.044899349153614126 0.15204775930494188 0.13358478781754288 0.07313603232538723 0.034154177808949346 0.07197642265584682 0.005481057771019321 0.15198418495820643 0.025213435181632615 0.09123128161062866 0.26119086056584506 0.08546276511544071 0.06526989963420737 0.07701444624168004 0.004630155725356707 0.502189058759374 0.0026925044692109237 0.09126849208455312 0.0011428678238950447 0.0008145442960506134 0.16951526585023124
# 模拟结果: (0.286, 0.2515, 0.028, 0.4345)
# 适应度: 0.011000000000000005
# diff: 0.06100000000000003
# 模拟用时 12 : 7.434338700771332 分钟
# Repeat 13:
# 最佳p值: 0.05820268295531627 0.18492081118113277 0.10774316465767056 0.008958374043128815 0.23316124749127254 0.0418727067124519 0.09643080106296262 0.001054394895606295 0.011878225896363283 0.2557775911040949 0.022339139233930674 0.13378964832119175 0.025179690060956057 0.0005807827135761091 0.14462527730701574 0.007287123930914339 0.1901469095795068 0.006301345032034226 0.019095005991199742 0.4506550778296745 0.17957283766205226 0.03952690654814716 0.06676004305520129 0.03859594814884886 0.17094439146135024 0.04190464678979904 0.15491307400147952 0.00516793316379516 0.03783073898623675 0.2647834801830897 0.037740025890272824 0.12962147777204786 0.15532989779269699 0.00017390803166752 0.5047433979718573 0.009302085078432621 0.0869792726175004 0.0032503814468194414 0.004740314603660808 0.06811923879504432
# 模拟结果: (0.302, 0.2525, 0.0225, 0.423)
# 适应度: 0.014000000000000005
# diff: 0.033000000000000015
# 模拟用时 13 : 7.4659355759620665 分钟
# Repeat 14:
# 最佳p值: 0.073124770242044 0.005485520892033802 0.000337557440784001 0.05141002013579311 0.33403713910376964 0.007866339232628578 0.25001532255623343 0.0004170546845916317 0.016602683960496814 0.26070359175162505 0.15731739327454838 0.10456334285653966 0.09406381660901321 0.03414218707660199 0.19685650971408622 0.012391641816305005 0.1539077694448526 0.03179462196387859 0.014467439933795496 0.20049527731037894 0.1133083781781983 0.02383511969456868 0.31871026929994517 0.10632460574181798 0.11234085328400469 0.04730486219277263 0.22143654637653687 0.005650363850998339 0.04464931197377944 0.0064396894073777645 0.14676447176009058 0.07003823576098801 0.08015734108766545 0.007037494126889239 0.21506619584295236 0.001198751562840654 0.3064847474397096 0.00505593194382019 0.019782868596615696 0.14841396187842815
# 模拟结果: (0.276, 0.246, 0.0355, 0.4425)
# 适应度: 0.017000000000000008
# diff: 0.092
# 模拟用时 14 : 7.522127676010132 分钟
# Repeat 15:
# 最佳p值: 0.040102603360478876 0.10203907742206077 0.030960035299579462 0.010016379308105644 0.1069413076364583 0.03465278358997616 0.5471975868637011 0.012153722992383941 0.03373091074238899 0.08220559278486676 0.13323582562136063 0.12411427059636079 0.2896770596354263 0.0054781900898686385 0.18674957907521095 0.023597944755418536 0.1914645181991354 0.00915859493250221 0.011872795724029333 0.024651221370687093 0.015519489743573136 0.16364668065799737 0.22634584183610573 0.05424353619861347 0.20497473201293667 0.04955398715630399 0.04511380481433671 0.06320531612627386 0.013095510462287388 0.16430110099157172 0.06346225861662161 0.11035626734718232 0.0471462007537992 0.004380881661455712 0.4888859140109313 0.01916887110394802 0.050113686047916176 0.000545536272570069 0.011755689473169172 0.20418469471240647
# 模拟结果: (0.2985, 0.2505, 0.0325, 0.4185)
# 适应度: 0.009000000000000005
# diff: 0.053000000000000026
# 模拟用时 15 : 7.431040120124817 分钟
# Repeat 16:
# 最佳p值: 0.04039285960060696 0.10243824181338972 0.022584827885720204 0.074867290803133 0.2811310769008922 0.0034600228614066514 0.2372438009631804 0.014569205373518529 0.008530185851000509 0.2147824879471517 0.02116849182617599 0.23986307712930974 0.22476076544292284 0.020493376423283572 0.11229881543193262 0.011155671007009845 0.3425542075623018 0.008440557472643672 0.013534693337086491 0.005730344367333534 0.16849094733260747 0.11435508048090004 0.031554706663324175 0.13846395532006064 0.28474830119458716 0.08413982455050394 0.09764286385307379 0.026477176781387248 0.017879938852334278 0.036247204971221206 0.06549645096560087 0.06181644052723259 0.09569224812477196 0.01140675930152133 0.4475067493725452 0.014262273736936336 0.11313756122865223 0.0014208792184207649 0.005614056502004458 0.18364658102231435
# 模拟结果: (0.307, 0.2495, 0.0345, 0.409)
# 适应度: 0.016000000000000007
# diff: 0.05700000000000003
# 模拟用时 16 : 7.517624648412069 分钟
# Repeat 17:
# 最佳p值: 0.04233711616688086 0.09273591271248954 0.034346505596159975 0.038300111252468204 0.30448935152233353 0.003835294575837685 0.2637174405911265 0.0013531847642387392 0.06532358248019428 0.15356150033827054 0.26220033507384916 0.10066509256830405 0.02261936834447548 0.02915203257538764 0.2581940783630956 0.012082869462761187 0.25483595724299957 0.007248147212503177 0.006872475266593181 0.04612964389003091 0.13422909227990823 0.028864597434380402 0.17368286328001342 0.0540825718959941 0.09222223847822113 0.08330508479347071 0.08476488701852894 0.0015883403975641309 0.027191645970178986 0.3200686784517398 0.1883171667157088 0.08889482897653014 0.01832547206151706 0.0038294517186279074 0.13289235760340667 0.0030380715890227397 0.259955509518415 0.005369681847804973 0.023067460525518602 0.27630999944344786
# 模拟结果: (0.2995, 0.212, 0.027, 0.4615)
# 适应度: 0.009000000000000005
# diff: 0.11300000000000004
# 模拟用时 17 : 7.544058728218078 分钟
# Repeat 18:
# 最佳p值: 0.00928561159062073 0.21268321823488642 0.08740830109765052 0.019057778373586652 0.45873262077059046 0.03285958893625578 0.010224970669502089 0.011786940247538501 0.031257005734099744 0.12670396434526907 0.08834422484431331 0.14784739372566788 0.17236701599208687 0.0035895905722697244 0.27897179344795603 0.001999589247844436 0.2778674792851548 0.00027088529459753577 6.22422620969341e-05 0.028679785328012315 0.24181356369193405 0.14734781013301962 0.14588919532940653 0.0775119602872955 0.04096330082865904 0.009399457720178292 0.03682000337346683 0.03837790971688534 0.02429831833370399 0.23757848058545064 0.05498766595471977 0.13503179069489857 0.008615289702186555 0.008259116536903064 0.29507893330842305 0.001012411484823077 0.3057484659532082 0.0028424545145301306 0.00217156319550635 0.18625230865480125
# 模拟结果: (0.291, 0.271, 0.0175, 0.4205)
# 适应度: 0.007000000000000003
# diff: 0.057000000000000044
# 模拟用时 18 : 7.45078680117925 分钟
# Repeat 19:
# 最佳p值: 0.04554283847033654 0.2886971202856494 0.01525597776985647 0.01781229052272976 0.19840487811845658 0.0008192100457739702 0.03307415117763119 0.0030728921138977955 0.041821620473136444 0.3554990210225318 0.20225292497507444 0.060276008604205525 0.2820312137484248 0.01679119993231191 0.021887394663461405 0.007414095048941789 0.1989988092350438 0.009694425590905895 0.005251757849222924 0.19540217035240734 0.27960422203943724 0.05484757028167934 0.040994583293205135 0.09810192298393433 0.15578174679761198 0.05460238702981072 0.21489023951003128 5.755673415115833e-05 0.0077533197772516075 0.09336645155288723 0.05028811153561898 0.09307645568422072 0.1154703353364446 0.008255414394681049 0.4289815137362365 0.001475388252426791 0.14683950949142302 0.0038681887918471875 0.008505881576226953 0.14323920120087413
# 模拟结果: (0.297, 0.2565, 0.023, 0.4235)
# 适应度: 0.008000000000000004
# diff: 0.03900000000000002
# 模拟用时 19 : 7.5575126051902775 分钟
# Repeat 20:
# 最佳p值: 0.0009169674352810175 0.12976086037784748 0.12531982789170776 0.032117525120261246 0.3547649784511942 0.010189080058613784 0.12755736976759124 0.014248291597668165 0.003237951572823836 0.2018871477270112 0.07725874373248906 0.19981266829906374 0.014615390226380224 0.007765918683376139 0.0068507718053503275 0.036261939878413106 0.39650371970443055 0.008941959256368483 0.0022236559222947264 0.24976523249183363 0.002091703333180546 0.18110307264427752 0.05513276417888625 0.008767525222504726 0.2797805910526938 0.1621734284659391 0.14660219509309805 0.1057310360766566 0.006488757201227229 0.05212892673153613 0.19098401242451005 0.10505910121399628 0.001169560919021868 0.01866204190860412 0.21263760080962707 0.0035054747485168654 0.22722340642893768 0.001646346618990335 0.007338646652300751 0.23177380827549499
# 模拟结果: (0.293, 0.2175, 0.038, 0.4515)
# 适应度: 0.011000000000000005
# diff: 0.11500000000000005
# 模拟用时 20 : 7.474201007684072 分钟
# Repeat 21:
# 最佳p值: 0.06203264332261439 0.11389579550234644 0.18802850431668222 0.03988306495811992 0.013014798178237025 0.0005896851558005653 0.13148968862714988 0.0019962050949084045 0.022948714525022337 0.4261209003191188 0.30291106099188425 0.11353786102305281 0.06172260222271831 0.018799263648946813 0.17273244691489667 0.11759147079256456 0.08322556082069042 0.013624824157216102 0.01611833015706165 0.09973657927096816 0.19103558168136214 0.12508785787186105 0.08349677118892825 0.003610468542780724 0.12978923597101258 0.0031450527233095656 0.3747895986786248 0.011640608719910342 0.05201183588180984 0.0253929887404006 0.10809628498143142 0.13732987475034203 0.1166745610028378 0.009927764246264148 0.30324589692151493 0.0007964099072700948 0.09539431162075519 2.614922785380593e-05 0.0011380649312595986 0.22737068241047098
# 模拟结果: (0.318, 0.2575, 0.0255, 0.399)
# 适应度: 0.01800000000000001
# diff: 0.05399999999999997
# 模拟用时 21 : 7.3862741986910505 分钟
# Repeat 22:
# 最佳p值: 0.04284218472755454 0.0923594068627035 0.030806731759458524 0.027677625138118073 0.1264947614080443 0.013953351858326609 0.33117642896308874 0.00024372683652645294 0.021287420975085524 0.3131583614710938 0.13921410157745237 0.262373988385487 0.11128068182930538 0.12761798978990405 0.008338977206081347 0.003946137411580016 0.17066355289568852 0.017800658234092718 0.009513150642746132 0.1492507620276627 0.10462447335308092 0.1518752941173874 0.1761773169713473 0.03686956235675 0.084241612529588 0.06581248620135043 0.08942920271096245 0.0008174664769400695 0.08926160238065456 0.20089098290193888 0.003986836310615192 0.26692735507588644 0.017727334014168445 2.9112789619753968e-06 0.460268547293505 0.0006222744525220255 0.14280675857692815 0.01713208527492717 0.0022070643869313415 0.0883188333355542
# 模拟结果: (0.308, 0.23, 0.0405, 0.4215)
# 适应度: 0.009000000000000005
# diff: 0.069
# 模拟用时 22 : 7.424562438329061 分钟
# Repeat 23:
# 最佳p值: 0.04805317559131828 0.06136493829919093 0.05734359700190565 0.0023730555406860075 0.24694967050211936 0.005070019171717501 0.26821132725240127 0.004629475119859066 0.02595729201879675 0.2800474495020051 0.121199177378513 0.12451851653172562 0.05531937468724788 0.017462349336332485 0.17113018919021533 0.00910040519203525 0.18287674449709712 0.008117717543089075 0.04682288087222208 0.26345264477152225 0.10249175068519538 0.23631833726686802 0.04488878566717605 0.015604666427114446 0.22614735349753573 0.06989164721246605 0.033880137748259445 0.014560799452417264 0.06690336160645018 0.18931316043651764 0.06430572479198643 0.22462906583794343 0.057149371658908786 0.012667448614488916 0.3069586682601116 0.0004603533968371123 0.2192170320153889 0.002094423169635007 0.007282522542317623 0.10523538971238232
# 模拟结果: (0.285, 0.2485, 0.023, 0.4435)
# 适应度: 0.009000000000000006
# diff: 0.06900000000000005
# 模拟用时 23 : 7.553982106844584 分钟
# Repeat 24:
# 最佳p值: 0.014127709790231991 0.08958315740753893 0.08882237875814922 0.011605174225420139 0.23703597816389918 0.021872207934246265 0.18681003260148293 0.0023332518052721265 0.003342483469797221 0.344467625843962 0.1367790770016223 0.007398878739704038 0.10298405672831107 0.00810504198152855 0.4023065249507615 0.03863574582802484 0.20932718210709034 0.018114477448089143 0.005635075774456839 0.07071393944041146 0.15051821842639712 0.15291368612577882 0.07993418426672547 0.005058496455697186 0.11483481248238657 0.0028594989370879947 0.28825521878751487 0.02124792568278994 0.1343710291221043 0.05000692971351785 0.08888810754550802 0.2131006560420066 0.024468285914345012 0.008832315995537632 0.3062889584701291 0.0036743600628079895 0.20740004176847057 0.005633475421467302 0.002841579361364569 0.13887221941836306
# 模拟结果: (0.325, 0.229, 0.024, 0.422)
# 适应度: 0.012000000000000005
# diff: 0.05800000000000001
# 模拟用时 24 : 7.627997477849324 分钟
# Repeat 25:
# 最佳p值: 0.042638123877240905 0.06132610030357346 0.08883767698432794 0.06777035308704245 0.31931017594212363 0.019469932522007266 0.0018643878599655952 0.00024388503937708956 0.011238543610239835 0.3873008207741019 0.4011010475565727 0.015746362096921197 0.1220796247606738 0.01592937284253436 0.1779637595968592 0.005033286892972704 0.06214609839376883 0.0045575448257984316 0.03661605857688805 0.15882684445701079 0.011696486557758174 0.14216690684845174 0.05106421932721 0.08884178336311066 0.17202861153100646 0.13890021869156483 0.05929074956717051 0.006369869682973015 0.03665649192087402 0.29298466250988053 0.11941748661712026 0.21104809549674952 0.06198120922106269 0.0002987668216752106 0.1263184512228763 0.0012257815257041699 0.3098238924638606 0.005597035903308844 0.019705944841968453 0.14458333588567387
# 模拟结果: (0.3225, 0.248, 0.0335, 0.396)
# 适应度: 0.005000000000000003
# diff: 0.07199999999999998
# 模拟用时 25 : 7.606870953241984 分钟
# Repeat 26:
# 最佳p值: 0.05107126745403047 0.16186881421112365 0.0745441144758461 0.0036676355480455493 0.19328920158998217 0.023284017458381483 0.13536882446303228 0.00020305838555391477 0.012064410167807531 0.3446386562461969 0.009243393112782156 0.27296035606924884 0.21131594730426767 0.0308632255571541 0.1568261656750753 0.0069250826600614455 0.22721478422207605 0.013994096699957118 0.017020848805712925 0.053636099893664656 0.0026191354299139034 0.1392033582518758 0.14174553514135288 0.07880469137428106 0.1099766873148807 0.06368809695692447 0.16735559730576824 0.010433174522666771 0.26511298588496 0.021060737817376187 0.11417785579351682 0.10402467806102045 0.14373414785236951 0.006719683059123997 0.390389094773012 0.009285922279607532 0.0005054020469170605 8.984617058490875e-05 0.016128672882383847 0.2149446970814641
# 模拟结果: (0.3055, 0.2565, 0.0285, 0.4095)
# 适应度: 0.015000000000000008
# diff: 0.050000000000000024
# 模拟用时 26 : 7.58032386302948 分钟
# Repeat 27:
# 最佳p值: 0.03569051988728512 0.10260931101105718 0.03828541956424318 0.027086638997484418 0.20341366274622041 0.02495548127534532 0.3371711704674317 0.02215938952381161 0.06508534773277935 0.14354305879434173 0.23570653341264455 0.2893597781866301 0.009305439846024478 0.03677983358843328 0.10718325636171447 0.019616478598115744 0.20186243136897244 0.005157617936535733 0.012421944475442415 0.08260668622548678 0.11855431211333921 0.20682373272687513 0.14259317264742352 0.002232676253718043 0.08047802403865992 0.022138313356233872 0.27142212415671957 0.0059012354354357425 0.07739625006865797 0.07246015920293693 0.08636580811205591 0.040700918066423133 0.07907326535713104 0.0032805647047854207 0.2947854535594651 0.019806438394838793 0.26233470505323775 0.001417068500406976 0.009103484587967583 0.20313229366368826
# 模拟结果: (0.257, 0.258, 0.0445, 0.4405)
# 适应度: 0.011000000000000006
# diff: 0.11400000000000002
# 模拟用时 27 : 7.717849751313527 分钟
# Repeat 28:
# 最佳p值: 0.06428685093006069 0.03591094820615942 0.0004254583631066121 0.019161566825464535 0.30164036244255626 0.026937452953708224 0.1895832900507353 0.0022515445765964297 0.01914463330906404 0.3406578923425484 0.1434832266870979 0.2171323501788849 0.04941962269254178 0.030779911966776232 0.16347963917084518 0.015686794862297036 0.11369120380817758 0.07688384824577901 0.030450091937803687 0.15899331044979684 0.15707980182942982 0.1284397538021615 0.033670190877837854 0.03462473329989139 0.021860184714258758 0.12809001677147072 0.26748732937125935 0.013770423879593001 0.002925413510441817 0.2120521519436557 0.15363244451632152 0.1345061746760735 0.18060328201630985 0.0033490215001009964 0.19963123783186812 0.005588991218199808 0.08084379211753866 0.01092404262700427 0.001660888961592237 0.22926012453499084
# 模拟结果: (0.314, 0.2395, 0.0365, 0.41)
# 适应度: 0.011000000000000005
# diff: 0.061000000000000026
# 模拟用时 28 : 7.8118035912513735 分钟
# Repeat 29:
# 最佳p值: 0.01904749359782139 0.12717335277844594 0.16600480244824925 0.027805931806132538 0.19444110511683965 0.00618742647309374 0.2393691471990809 0.0022481037157736773 0.010149971320620841 0.20757266554394185 0.16083058867480518 0.22098522641257812 0.0386830167526647 0.016196711567325224 0.0912715121907282 0.028075206897337276 0.07132048066078765 0.0033480502231531158 0.007273842961370818 0.36201536365924986 0.1383765552947004 0.09866989289446244 0.03509620551240384 0.021845303005872212 0.03594256148811205 0.035576020389530914 0.12577012083300673 0.14426625857814088 0.04574591323883755 0.31871116876493316 0.06107035271558374 0.14676070503754596 0.09457510851095322 0.032165241753549706 0.3469684543319179 0.008817724019520724 0.27932079072258575 0.000394190049445762 0.023162587774779766 0.0067648450841175265
# 模拟结果: (0.2895, 0.318, 0.0275, 0.365)
# 适应度: 0.031000000000000014
# diff: 0.171
# 模拟用时 29 : 7.805497761567434 分钟
# Repeat 30:
# 最佳p值: 0.011879831686815537 0.11050698645437232 0.19641131236856316 0.03418284251003039 0.3970417249415296 0.012874206908904125 0.005013288686649842 0.0037075241613360723 0.023700331789611284 0.2046819504921876 0.2344049605263764 0.11928586161255708 0.06123543954860146 0.0036330338890430427 0.2544387629147057 0.024825955787463137 0.07283473883361799 0.001227613724423336 0.020440662880188493 0.20767297028302334 0.17728792583855998 0.2618832293143157 0.11780333255846953 0.009107936828850227 0.023375724796989697 0.013624929233239626 0.20751250005631416 0.009738806818729389 0.024310738794874623 0.155354875759657 0.14051276060703546 0.018861333059010634 0.0703941409271975 0.00013527117798592156 0.3059508677183001 0.015533838525270193 0.3135986349761499 1.4842804097955568e-05 0.007842671981509024 0.1271556382234434
# 模拟结果: (0.332, 0.235, 0.0205, 0.4125)
# 适应度: 0.009000000000000005
# diff: 0.06500000000000004
# 模拟用时 30 : 7.852178287506104 分钟
# Repeat 31:
# 最佳p值: 0.013502700289514913 0.10620855191065744 0.04291704590696962 0.011335168172595571 0.17204725366438633 0.011948882946187147 0.36493560589517204 0.014834939552634235 0.003713203563886809 0.2585566480979959 0.05603950289563421 0.011725305804501259 0.2524710598230781 0.024219228866062474 0.2648815382721913 0.0133649382759591 0.05276425719324274 0.03257166424917905 0.009211517029836044 0.2827509875903157 0.231006277915006 0.06271528825610882 0.14855800332088845 0.009056003715161184 0.0480118527154369 0.08000772533478379 0.17843297736711616 0.033014397760975436 0.003634753041627002 0.20556272057289615 0.17900281698914255 0.05431987939015018 0.09498104267485863 0.0027024768026076306 0.37928217812910636 0.0035387396668148706 0.262068958715271 0.0035884829872408893 0.012220731168041931 0.008294693476765898
# 模拟结果: (0.284, 0.2705, 0.0285, 0.417)
# 适应度: 0.003000000000000001
# diff: 0.07800000000000004
# 模拟用时 31 : 7.876689410209655 分钟
# Repeat 32:
# 最佳p值: 0.03537591854693328 0.17022717493653894 0.0633300204481041 0.04681134449870588 0.029049081009988265 0.006416156801372887 0.4388943435156647 0.003511273692389268 0.01655786967597566 0.18982681687432687 0.23440377345704883 0.19774831172825583 0.17996250927493887 0.04381311815960542 0.11785061292693748 0.013658496898285563 0.01531130165009486 0.018514317333204793 0.025817480617967972 0.1529200779536605 0.02330023479441867 0.14858210757289664 0.1607541084706628 0.00012864190525661216 0.32898175697670295 0.020077320319326408 0.046120109934889235 0.04784872255458972 0.059743487221451244 0.1644635102498057 0.08729350418168896 0.08694103303558312 0.06411385633789747 0.0502800173093457 0.36318382051444886 0.026437319216306387 0.20288994251889375 0.004017644105375912 0.010232505183124305 0.10461035759733532
# 模拟结果: (0.299, 0.2675, 0.045, 0.3885)
# 适应度: 0.015000000000000008
# diff: 0.10500000000000001
# 模拟用时 32 : 7.836377231280009 分钟
# Repeat 33:
# 最佳p值: 0.017402271949125702 0.30414890431309216 0.07314090751915059 0.05889447298796153 0.16656239725373467 0.008030008385165424 0.06279442365221749 0.0022421098427351043 0.011781822934505174 0.29500268116231215 0.1289734797068043 0.05441639904232727 0.1670082902453983 0.04293199675357202 0.3571339720010128 0.005490547135921951 0.052000854916709846 0.010946839667790234 0.014959515521245146 0.1661381050092182 0.051023980057960966 0.25314698180859174 0.007382563220380252 0.05764074590607577 0.11891333475538206 0.05914794608582319 0.09348549139145078 0.015334035100774922 0.07883569998776914 0.2650892216857912 0.037088612253505716 0.1361360339120894 0.05499468769388834 0.0033974840343330925 0.3199253111533032 0.018158648507243146 0.2592725817585371 0.02354936089075156 0.023645058914451934 0.12383222088189644
# 模拟结果: (0.272, 0.272, 0.05, 0.406)
# 适应度: 0.011000000000000008
# diff: 0.12399999999999997
# 模拟用时 33 : 7.821569013595581 分钟
# Repeat 34:
# 最佳p值: 0.0819588895650055 0.14881834097153085 0.36216688025624033 0.006480706594994764 0.04832315522748346 0.023347745997847974 0.07097473381881717 0.0018669113967362254 0.009583478534284618 0.24647915763705916 0.05407159493876252 0.021795477606943236 0.09532501698039722 0.029606787742061845 0.21340966461478433 0.020890649614462006 0.010608176718807844 0.017324425400227363 0.016974763082500764 0.5199934433010529 0.09760229389148861 0.07057896033786755 0.009700103601398245 0.18363032367054832 0.0022932723496777102 0.03623887144990139 0.2505846469245126 0.08541899338066868 0.202413446722004 0.061539087671932856 0.06941968418038115 0.055650067687190365 0.12082674299345765 0.0028002782643788493 0.5098438140134802 0.0008237140317979971 0.08776043663714872 0.0031237227953190717 0.04478469264680046 0.10496684675004538
# 模拟结果: (0.288, 0.249, 0.0425, 0.4205)
# 适应度: 0.02000000000000001
# diff: 0.07300000000000004
# 模拟用时 34 : 7.757639161745707 分钟
# Repeat 35:
# 最佳p值: 0.07483360771750072 0.0174954434009267 0.08811871853025849 0.09326245107301616 0.03178002282558139 0.03470055662055813 0.3444564207021204 0.007793850730024923 0.045856417465252514 0.26170251093476055 0.1388394505297465 0.24827924238202692 0.0716154769173128 0.0050805758657606745 0.3315905875876529 0.02182696551706159 0.011968052523749991 0.011644026560911987 0.050540771067890865 0.10861485104788568 0.23128475610652743 0.06321368806025637 0.05827061160677208 0.053066111738005205 0.23724353338804333 0.20694114685831055 0.06507137043767039 0.007878739687748859 0.03683759831606078 0.04019244380060491 0.10033043266975418 0.29828408198316875 0.10708143676650667 0.015105273916860751 0.09005968926755585 0.01177789216401543 0.050375042960871724 0.0025618379836344664 0.018283068030651488 0.3061412442569806
# 模拟结果: (0.29, 0.261, 0.0555, 0.3935)
# 适应度: 0.017000000000000008
# diff: 0.113
# 模拟用时 35 : 7.9590087890625 分钟
# Repeat 36:
# 最佳p值: 0.046656227494898554 0.13287553383852396 0.018138886933108625 0.004664504768289012 0.28277029421713695 0.008413000194349398 0.14182399394986334 0.034760140962809334 0.0007231748055579319 0.3291742428354629 0.30893900533342383 0.14448153165366667 0.03071952956750538 0.00533425753602186 0.15362507805827985 0.0377013400043571 0.13618774363815708 0.00046316649532637306 0.006581694088622114 0.1759666536246397 0.24675221233665293 0.13808037121792752 0.020679000871542834 0.0490013391872952 0.01599778199032248 0.061706891226566564 0.2647661720816534 0.08359120123811391 0.021468499513654718 0.09795653033627065 0.2281034858515855 0.012188236311842307 0.11317223535524726 0.0056551957420402105 0.12452568964862643 0.022703560832905957 0.33948379741599743 0.0010685517170907456 0.007850621306400421 0.14524862581826353
# 模拟结果: (0.3145, 0.257, 0.0245, 0.404)
# 适应度: 0.011000000000000005
# diff: 0.04399999999999997
# 模拟用时 36 : 8.340129427115123 分钟
# Repeat 37:
# 最佳p值: 0.06257265851322093 0.11431793375795522 0.26012140886358964 0.007965579910475062 0.019664401820564843 0.03692386851509526 0.14913651474015963 0.006592587154890007 0.0036450345775482064 0.3390600121465012 0.14116774094074974 0.011639919372800598 0.14907216629580863 0.00607742821370137 0.2603262487050245 0.08926561380510419 0.11188074455246948 0.0002628759792769028 0.060888416696997974 0.16941884543806665 0.16280493277595973 0.2555350357372595 0.12594153295918253 0.012548087294194089 0.09591933051338129 0.00600156638699993 0.12516482081446187 0.003413538834765572 0.11378246673160124 0.09888868795219405 0.14037737913437512 0.006520788026179635 0.10292530519492361 0.001350486733520602 0.45577140213851736 0.001644848548310362 0.09633874669291949 0.0043498205591453835 0.00039505931542811555 0.19032616365668037
# 模拟结果: (0.3085, 0.2355, 0.0295, 0.4265)
# 适应度: 0.007000000000000003
# diff: 0.04800000000000002
# 模拟用时 37 : 8.279579150676728 分钟
# Repeat 38:
# 最佳p值: 0.041956051290709034 0.12428361196815371 0.0030320165130967008 0.04714198127054951 0.14907178150885245 0.005980551681238491 0.38803176658657024 0.004019342563792308 0.005187092973510169 0.2312958036435273 0.43339415596456193 0.02148719875418742 0.16124639030711227 0.014200090401747854 0.15104756740704603 0.030708401448228326 0.03579675068201566 0.003933337636570512 0.03732033835869611 0.11086576903983379 0.1914516005186661 0.08353728871677266 0.1686180882079071 0.07670362282396079 0.024607286930545536 0.009659080529131794 0.21481773923335143 0.05860800036473615 0.04319731718108753 0.1287999754938408 0.11480545073220944 0.2096544544269605 0.10119790281264415 0.001873076142743179 0.16651878220691432 0.0005742325327918668 0.02458761994213424 0.006909980836838745 0.0007501682745168167 0.3731283320922467
# 模拟结果: (0.308, 0.239, 0.0265, 0.4265)
# 适应度: 0.006000000000000004
# diff: 0.042000000000000016
# 模拟用时 38 : 7.907454562187195 分钟
# Repeat 39:
# 最佳p值: 0.062469732346576094 0.032888279203994536 0.22444329479288383 0.059676999080775076 0.24233066714883117 0.021870866929318708 0.08332009154850312 0.0032039055133360216 0.021561453774400236 0.24823470966138128 0.08689229547761769 0.07771026051763155 0.09985331330754511 0.02227991960579682 0.22765412048347794 0.011861796084609112 0.21303949934054534 0.050834412707011216 0.04512304815920222 0.16475133431656305 0.1114830423969587 0.2892311091039232 0.10002339779822057 0.023574919561910778 0.04401227534566463 0.012178555018925081 0.13168525054177824 0.03340925851099482 0.12389075431917493 0.13051143740244908 0.11971642555786507 0.06367269600071888 0.15351038995976893 0.004653501284442799 0.3948917771434616 0.007630038791593831 0.10045752496950607 0.0010669782669519448 0.023494248570015 0.13090641945567577
# 模拟结果: (0.308, 0.2465, 0.0375, 0.408)
# 适应度: 0.017000000000000008
# diff: 0.06300000000000003
# 模拟用时 39 : 7.719944417476654 分钟
# Repeat 40:
# 最佳p值: 0.1603294618464952 0.11492288539536512 0.08883154136826946 0.0034133895942993456 0.24062628857603702 0.016511570590570877 0.213680708098307 0.002300050351183964 0.008783582564897929 0.15060052161457413 0.11685850287817898 0.04958349901184337 0.13526980924982077 0.001230265986330874 0.0723597819878479 0.019589586194224462 0.208160083975974 0.023147601905993735 0.026013752526107596 0.3477871162836784 0.012738432879102984 0.08857787946971328 0.04223068736461195 0.03204521554154529 0.20156772359670722 0.04169443636980307 0.042986508004534574 0.04349625255689194 0.05349275525424006 0.44117010896284947 0.20256927143498513 0.01096826150298892 0.09362193726835781 0.0554146553678232 0.17770369677839165 0.003962742186887325 0.2680704953726869 0.005891759756600494 0.024569900825406728 0.15722727950587184
# 模拟结果: (0.315, 0.242, 0.04, 0.403)
# 适应度: 0.008000000000000004
# diff: 0.06999999999999998
# 模拟用时 40 : 8.15147963364919 分钟
# Repeat 41:
# 最佳p值: 0.05738765255046527 0.01294410788083206 0.003048760658462795 0.009504068987897945 0.23965653871711445 0.005050227956185583 0.06111239146577724 0.0014456304285948365 0.09926810270332288 0.5105825186513471 0.06271865350036908 0.09903029712067353 0.20180915331014546 0.03767000608301364 0.1555766565474733 0.032426787440227395 0.2584449607411376 0.007245205220514746 0.031211368704278996 0.11386691133216624 0.08626957610305243 0.1647883483101016 0.019983061382622794 0.008119165984903304 0.1738769693357421 0.031385140835973234 0.010784778598408465 0.012934414512646044 0.045409594592471646 0.4464489503440784 0.06208824907346399 0.13541633641946813 0.12384235174174775 0.0018984791146918068 0.49822519325688985 0.009213333356267303 0.13430673749585054 0.0013068898502140304 0.002822767434641116 0.030879662256765514
# 模拟结果: (0.307, 0.2025, 0.0305, 0.46)
# 适应度: 0.011000000000000005
# diff: 0.11700000000000002
# 模拟用时 41 : 8.034163482983907 分钟
# Repeat 42:
# 最佳p值: 0.07473564163771591 0.12912673648998418 0.04160851989418077 0.002306349909993072 0.3099361647161325 0.0024751355983493257 0.21168382499356528 2.192110974214094e-05 0.003772749576687076 0.22433295607364967 0.15753204518330136 0.2244705221963808 0.08221059452767376 0.0160537517884196 0.18407075894016878 0.028263115044847773 0.1489124535433451 0.01122462592276255 0.0276882659869374 0.11957386686616264 0.28390648914784306 0.18658717245032747 0.05279725103890257 0.04295815714944882 0.08650625095518265 0.011156067576022177 0.29465963714652277 0.001792939819178193 0.01484087340299374 0.024795161313578517 0.05526967567129483 0.2057576823863725 0.00686263124611084 0.008570529096040138 0.23895756162142262 0.002136538467748589 0.274160432667011 0.009296144218950739 0.011134264426316669 0.1878545401987321
# 模拟结果: (0.306, 0.2495, 0.032, 0.4125)
# 适应度: 0.012000000000000005
# diff: 0.052000000000000025
# 模拟用时 42 : 8.128243045012157 分钟
# Repeat 43:
# 最佳p值: 0.09129612971289856 0.11968536211768713 0.3083904109606028 0.030340699466299796 0.18715792978964801 0.006403354645295836 0.133612768831285 0.010429369127325613 0.006955657946233294 0.10572831740272391 0.3205283833338686 0.018958317013536792 0.011202179093459524 0.06308870638640574 0.15652584455015933 0.005732216238244602 0.12289214308601011 0.0008948185566118849 0.029732502912628505 0.2704448888290749 0.054405238180317984 0.21560443185185862 0.06580478899921985 0.06458735187149642 0.12776528228299394 0.05841985324168328 0.07865056308325002 0.010054121761716309 0.19978871584523372 0.12491965288222981 0.10610937134996375 0.19644558915484844 0.040054036050941856 0.0008881549259226985 0.22070203369159136 0.004061027089472697 0.17740936776804755 0.006859910374536694 0.019867668880212238 0.22760284071446263
# 模拟结果: (0.317, 0.269, 0.0315, 0.3825)
# 适应度: 0.009000000000000005
# diff: 0.087
# 模拟用时 43 : 8.085839811960856 分钟
# Repeat 44:
# 最佳p值: 0.07936542625540609 0.020032333252462627 0.02011706712617415 0.011175926731856781 0.30092381457721673 0.023311209406370107 0.15530416487968887 0.004151274944942343 0.02946570190887706 0.35615308091700515 0.20748038838887356 0.01525480180166452 0.17646561909713812 0.02260533238247793 0.11698428549456706 0.014167705679614452 0.3199681973203546 0.01573366854255773 0.024994812009539336 0.08634518928321282 0.1314407387049164 0.1218782484848074 0.28953469714898894 0.09786173283482415 0.155230843081921 0.04895076150920191 0.0530617104739641 0.03978458834600453 0.042826214300230175 0.01943046511514127 0.11900174268248032 0.08807539375942718 0.12367696691675538 0.0014775831807268144 0.329204229965884 0.027704322468704422 0.21152646814370746 0.00357295424622836 0.01173626932941332 0.08402406930667254
# 模拟结果: (0.3215, 0.25, 0.035, 0.3935)
# 适应度: 0.011000000000000005
# diff: 0.07299999999999998
# 模拟用时 44 : 7.678611361980439 分钟
# Repeat 45:
# 最佳p值: 0.056400949831339926 0.025956232092479888 0.10839901505954613 0.020001599203597575 0.1729215666401511 0.012881269508553086 0.37701623457833083 0.00047819120933330003 0.012346433025242232 0.21359850885142587 0.05986353709845761 0.17171303239076682 0.04132059723030151 0.004222560934246853 0.1910721651944667 0.000788162944388462 0.07135511436007744 0.0005302243221283591 0.0030245512515500923 0.4561100542736161 0.32262946556638233 0.1378099533864578 0.05136227621898339 0.06869954271436772 0.19286062840333001 0.0037665703029244337 0.0484234860926146 0.03564085051768559 0.061796171942549716 0.07701105485470447 0.13158244539638297 0.31514686401194825 0.055022524556220684 0.002435673250548627 0.20286105836335339 0.013255915558031876 0.040327537913189646 0.018612837203422352 0.0005866951925913203 0.22016844855431086
# 模拟结果: (0.325, 0.2495, 0.028, 0.3975)
# 适应度: 0.008000000000000004
# diff: 0.06599999999999998
# 模拟用时 45 : 7.597970700263977 分钟
# Repeat 46:
# 最佳p值: 0.05746356680708381 0.12399701683000854 0.1031979991807056 0.011997570554752122 0.2159827061616389 0.020117005625091233 0.21868559298072504 0.03576723546048581 0.006113652841762345 0.2066776535577466 0.17619205291276904 0.08186241818843978 0.1176357659873427 0.0011383920284962637 0.20533725296738528 0.004794391127210199 0.022935885488772102 0.021741745140335327 0.02775229004607823 0.3406098061131712 0.1292924252059383 0.21836725677050497 0.14604186144374282 0.06623527574189851 0.0839874191945653 0.011077001165946104 0.22944265610596687 0.01997412321398638 0.03161622257447115 0.06396575858297959 0.10928824328261162 0.09461189821390092 0.12022243633536624 0.003168058884003528 0.3380297863667523 0.000977891537638049 0.19137640611139453 0.003954809532755546 0.014770548005228453 0.12359992173034881
# 模拟结果: (0.3135, 0.2715, 0.025, 0.39)
# 适应度: 0.02000000000000001
# diff: 0.073
# 模拟用时 46 : 7.653749183813731 分钟
# Repeat 47:
# 最佳p值: 0.006741107088463296 0.11469181699705165 0.027498202409448336 0.012946136264688853 0.2149067530004952 0.024296430023925713 0.35497628494448696 0.013190294661757281 0.002613341317655908 0.22813963329202677 0.06504819120774834 0.06730685291071188 0.0716892475721458 0.002533933861474278 0.24026347840934195 0.0032218470721849905 0.10787881083749669 0.0022291702909074196 0.026209172602816046 0.4136192952351725 0.1472031190206018 0.04442722659705195 0.17527761938789854 0.10637300463456784 0.09883595754184989 0.028304484291052732 0.18113963931496602 0.022174517266508095 0.06988928995884688 0.1263751419866563 0.0028215208370695423 0.30439966509111466 0.029168005300695556 0.004568502258735002 0.4087918002259363 0.0106374571240374 0.21132154367239225 0.0013779185994904984 0.010137090659400492 0.016776496231128403
# 模拟结果: (0.2855, 0.267, 0.0255, 0.422)
# 适应度: 0.009000000000000005
# diff: 0.06500000000000003
# 模拟用时 47 : 7.513093407948812 分钟
# Repeat 48:
# 最佳p值: 0.1766164375151438 0.05630159718974459 0.07186068255292209 0.005644453446364637 0.2954394409302105 0.03227316058470503 0.16954958387832814 0.0011116626034770845 0.0050381331924273295 0.18616484810667655 0.18958152221260302 0.20650707659878212 0.06350380897886646 0.00405374077783151 0.21044400619868958 0.020037843244510512 0.13295385673604784 0.01661065257072522 0.025878239133456077 0.13042925354848758 0.15800480577482773 0.08339907256101343 0.3338789738779999 0.03355370268381651 0.0755844673001282 0.02044549541581822 0.14488270372971268 0.0369723238679113 0.05006146555785124 0.06321698923092063 0.050250723781560945 0.168720694528365 0.0863434806413724 0.002033269070319732 0.26195709512041854 0.0011821580817258522 0.18990774216806638 0.00047280609083562476 5.370068215926785e-05 0.23907832983517618
# 模拟结果: (0.312, 0.2625, 0.0235, 0.402)
# 适应度: 0.009000000000000006
# diff: 0.05199999999999998
# 模拟用时 48 : 7.796238088607788 分钟
# Repeat 49:
# 最佳p值: 0.04966951145784719 0.14085061333149246 0.13526913328023535 0.0005230273922141686 0.167652101516257 0.04397788863738009 0.1421338363721448 0.03930444780200146 0.009028523281523199 0.27159091692890425 0.011406106006247203 0.25886611960365574 0.05067186871387677 0.01108935680664172 0.16498146624111748 0.11471369250455707 0.12031786959567764 0.010117826671139514 0.025064137226401308 0.23277155663068563 0.06544841625624907 0.06712384695643675 0.25406555551569376 0.08775778805066123 0.021377882698396543 0.04248911730967567 0.2399912336781512 0.05518395746420301 0.024171583352860456 0.14239061871767222 0.1290231695948995 0.17416062805508392 0.048866384985840464 0.005388276031407431 0.29879658187878544 0.00041332440947245704 0.15397877525886544 0.0031679370682602677 0.00974025540730826 0.1764646673100767
# 模拟结果: (0.298, 0.2525, 0.0325, 0.417)
# 适应度: 0.009000000000000005
# diff: 0.053000000000000026
# 模拟用时 49 : 7.756010464827219 分钟
# Repeat 50:
# 最佳p值: 0.05400711048761981 0.16119893649982572 0.10703505010123922 0.028949955508625308 0.20299941735452973 0.005708604431968352 0.182301566299951 0.01745147528918748 0.020391191384987847 0.21995669264206558 0.24537188556951897 0.037539503340981016 0.07953763642788243 0.0014178234047320822 0.14251380700469637 0.0040206781615271855 0.18344423814686892 0.011181300638622436 0.006676273342273231 0.28829685396289745 0.03768484110682897 0.15452591122367695 0.14700566002553317 0.04183807548217318 0.19122497554621445 0.1808343519007156 0.06735823958735633 0.022857874225057 0.1132873131781948 0.04338275772424949 0.11783170926755965 0.02122857683182612 0.0862142700819235 0.022854577246349077 0.34489317642314543 0.004282143894033116 0.20132943122414887 0.01060647269156669 0.025216135796997094 0.16554350654245042
# 模拟结果: (0.286, 0.214, 0.049, 0.451)
# 适应度: 0.02600000000000001
# diff: 0.13600000000000007
# 模拟用时 50 : 7.675169841448466 分钟

# %%
#用于测试突变是否会产生负数
from deap import base, tools
import random

# 定义个体的突变函数
toolbox = base.Toolbox()
# 在工具箱中注册自定义变异函数
toolbox.register("mutate", custom_mutate, mu=0, sigma=1, indpb=0.1)

# 假设 individual 是一个包含 40 个浮点数的列表
individual = [random.uniform(0, 1) for _ in range(40)]

# 检查突变前是否有负数
has_negative_before = any(x < 0 for x in individual)
print("突变前是否有负数:", has_negative_before)

print("突变前的 individual:", individual)

# 应用突变
toolbox.mutate(individual)

# 检查突变后是否有负数
has_negative_after = any(x < 0 for x in individual)
print("突变后是否有负数:", has_negative_after)
print("突变后的 individual:", individual)
# 将负数转换为正数
individual = [abs(x) for x in individual]

print("处理负数后的 individual:", individual)
# Out:
# 突变前是否有负数: False
# 突变前的 individual: [0.8572136738065249, 0.6138781666585785, 0.6111960875801277, 0.09495370693448779, 0.4805864698899758, 0.0022710956753931866, 0.29791321128916537, 0.18887016458268258, 0.16889046911903072, 0.6117106658421821, 0.6616204003328794, 0.1827473150316271, 0.931560455968166, 0.30985694522702656, 0.36217274202876104, 0.2510353581410142, 0.10957796588669211, 0.5888686550034109, 0.27702782188137265, 0.9260875407722358, 0.2857195142856328, 0.09683633318080376, 0.9686380985940389, 0.7261227131245555, 0.8106896513609652, 0.2342086098200038, 0.4292101377977736, 0.47611669265523116, 0.7965856992762514, 0.34140201091555544, 0.7201597593845486, 0.05308663910860134, 0.1438921711338278, 0.000231076124708407, 0.27823507206693465, 0.2913484020074719, 0.07884001158328624, 0.5845336332441464, 0.4711899521360444, 0.4825013949440018]
# 突变后是否有负数: False
# 突变后的 individual: [0.8572136738065249, 0.6138781666585785, 0.6111960875801277, 0.09495370693448779, 0.4805864698899758, 0.0022710956753931866, 0.29791321128916537, 0.18887016458268258, 0.16889046911903072, 0.6117106658421821, 0.6616204003328794, 0.1827473150316271, 0.931560455968166, 0.30985694522702656, 0.36217274202876104, 0.2510353581410142, 0.10957796588669211, 0.5888686550034109, 0.27702782188137265, 0.9260875407722358, 0.2857195142856328, 0.09683633318080376, 0.9686380985940389, 0, 0.8106896513609652, 1, 0.4292101377977736, 0.47611669265523116, 0.5754419729883669, 0.34140201091555544, 0.7201597593845486, 0.05308663910860134, 0.1438921711338278, 0.9739390626238906, 0.27823507206693465, 0.2913484020074719, 0.07884001158328624, 0.5845336332441464, 0.4711899521360444, 0.4825013949440018]
# 处理负数后的 individual: [0.8572136738065249, 0.6138781666585785, 0.6111960875801277, 0.09495370693448779, 0.4805864698899758, 0.0022710956753931866, 0.29791321128916537, 0.18887016458268258, 0.16889046911903072, 0.6117106658421821, 0.6616204003328794, 0.1827473150316271, 0.931560455968166, 0.30985694522702656, 0.36217274202876104, 0.2510353581410142, 0.10957796588669211, 0.5888686550034109, 0.27702782188137265, 0.9260875407722358, 0.2857195142856328, 0.09683633318080376, 0.9686380985940389, 0, 0.8106896513609652, 1, 0.4292101377977736, 0.47611669265523116, 0.5754419729883669, 0.34140201091555544, 0.7201597593845486, 0.05308663910860134, 0.1438921711338278, 0.9739390626238906, 0.27823507206693465, 0.2913484020074719, 0.07884001158328624, 0.5845336332441464, 0.4711899521360444, 0.4825013949440018]
